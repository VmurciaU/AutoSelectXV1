# %% [markdown]
# Paso 0 — Reset seguro de la colección (opcional)

# %%
# --- Paso 0: reset opcional de la colección para evitar "ruido" previo ---
import chromadb

VDB_PATH = "./vectordb"
COLLECTION_NAME = "langchain"

def reset_collection():
    client = chromadb.PersistentClient(path=VDB_PATH)
    try:
        client.delete_collection(COLLECTION_NAME)
        print(f"🧹 Colección '{COLLECTION_NAME}' eliminada.")
    except Exception as e:
        print(f"(info) No se eliminó colección (quizá no existía): {e}")

# Si quieres limpiar todo antes de reindexar:
# reset_collection()

# %%
# --- Paso 1: imports y utilidades ---
import os, re, pdfplumber
from typing import List, Tuple, Dict, Any
from collections import Counter

from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.schema import Document  # langchain_core.documents.Document en versiones nuevas

from dotenv import load_dotenv
import os

# Cargar variables del archivo .env
load_dotenv()

# Leer la API key desde el entorno
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")


# Patrones de limpieza (encabezados/pies repetidos del PDF ejemplo)
CLEAN_PATTERNS = [
    r"FORMATO REQUISICIÓN.*",
    r"ECOPETROL DESARROLLO DE PROYECTO.*",
    r"Todos los derechos reservados.*",
    r"EDP-F-046.*Versión.*",
    r"MR.*#:.*CAS.*",
    r"Página\s+\d+\s+de\s+\d+",
    r"_{6,}",  # líneas de subrayado largas
]

def clean_text(text: str) -> str:
    for p in CLEAN_PATTERNS:
        text = re.sub(p, "", text, flags=re.IGNORECASE)
    text = re.sub(r"[ \t]+", " ", text)
    text = re.sub(r"\n{3,}", "\n\n", text)
    return text.strip()


# Palabras clave para asignar prioridad (ES/EN)
HD_HINTS = [
    r"\bAPI\s*675\b", r"HOJA\s*DE\s*DATOS", r"\bDATA\s*SHEET\b", r"\bDATASHEET\b",
    r"BOMB(A|S)?\s+(DOSIFICADORA|DOSING)"
]

ALCANCE_HINTS = [
    r"\bALCANCE\b", r"ALCANCE\s+DEL\s+SUMINISTRO", r"\bSCOPE\b", r"SCOPE\s+OF\s+SUPPLY"
]

REQ_HINTS = [
    # Español: requisitos explícitos
    r"\bREQUISITO(S)?\b",
    r"\bREQUERIMIENTO(S)?\b",
    r"REQUISITO(S)?\s+T(É|E)CNICO(S)?",
    r"CONDICIONES?\s+T(É|E)CNICAS?",
    r"CRITERIOS?\s+DE\s+DISE(Ñ|N)O",
    r"DATOS?\s+DE\s+DISE(Ñ|N)O",

    # Inglés: requisitos explícitos
    r"\bREQUIREMENT(S)?\b",
    r"DESIGN\s+REQUIREMENT(S)?",
    r"TECHNICAL\s+REQUIREMENT(S)?",
    r"\bSPECIFICATION(S)?\b",
    r"MINIMUM\s+REQUIREMENT(S)?",

    # Español: frases prescriptivas comunes
    r"\bEL\s+PROVEEDOR\s+DEBE\b",
    r"\bEL\s+VENDEDOR\s+DEBE\b",
    r"\bDEBERÁ\b",
    r"\bSE\s+REQUIERE(N)?\b",

    # Inglés: frases prescriptivas comunes
    r"\bSHALL\b",
    r"\bMUST\b",
    r"\bIS\s+REQUIRED\s+TO\b",
]


NORM_HINTS = [
    r"\bNORMAS?\b", r"\bEST[ÁA]NDA(RE|R)E?S?\b",
    r"\bC(Ó|O)DIGO(S)?\b", r"\bCODE(S)?\b", r"\bSTANDARD(S)?\b",
    r"\bSPEC(S|IFICATIONS)?\b", r"\bREGULATION(S)?\b",
    r"\bRETIE\b", r"\bAPI\b", r"\bASTM\b", r"\bASME\b", r"\bIEC\b", r"\bIEEE\b",
    r"APPLICABLE\s+(CODES|STANDARDS|SPECIFICATIONS)"
]


def matches_any(text: str, patterns: List[str]) -> bool:
    return any(re.search(p, text, flags=re.IGNORECASE) for p in patterns)

def detect_priority(text: str) -> str:
    if matches_any(text, HD_HINTS):      return "hoja_datos"
    if matches_any(text, ALCANCE_HINTS): return "alcance"
    if matches_any(text, REQ_HINTS):     return "requisito"
    if matches_any(text, NORM_HINTS):    return "norma"
    return "general"

def table_to_text_and_kv(rows: List[List[str]]) -> Tuple[str, Dict[str, str] | None]:
    """Convierte una tabla (lista de filas) a texto legible y, si parece key-value (2 columnas), devuelve un dict kv."""
    clean_rows = []
    for r in rows:
        if not r:
            continue
        rr = [(c or "").strip() for c in r]
        if any(rr):
            clean_rows.append(rr)

    kv = None
    if clean_rows and max(len(r) for r in clean_rows) <= 2 and len(clean_rows) >= 2:
        kv = {}
        for r in clean_rows:
            if len(r) >= 2 and r[0] and r[1]:
                kv[r[0]] = r[1]

    text = "\n".join(" | ".join(r) for r in clean_rows)
    return text, kv if kv else None


def kv_from_text_page(text: str) -> Dict[str, str]:
    """Extrae pares clave-valor típicos de una Hoja de Datos por regex"""
    t = " ".join(text.split()).upper()
    kv = {}

    m = re.search(r"(\d+(?:[.,]\d+)?)\s*GPH", t)
    if m: kv["caudal_gph"] = m.group(1)

    m = re.search(r"@\s*(\d+(?:[.,]\d+)?)\s*PSI", t)
    if m: kv["presion_psig"] = m.group(1)

    m = re.search(r"(\d+)\s*-\s*(\d+)\s*CPS", t)
    if m:
        kv["rango_cps_min"] = m.group(1)
        kv["rango_cps_max"] = m.group(2)

    m = re.search(r"(\d+(?:[.,]\d+)?)\s*HP", t)
    if m: kv["hp_motor"] = m.group(1)

    m = re.search(r"\b(\d+)\s*\+\s*(\d+)\b", t)
    if m:
        kv["bombas_operativas"] = m.group(1)
        kv["bombas_respaldo"] = m.group(2)

    if "304" in t: kv["material_tanque"] = "304SS"
    if "316" in t: kv["material_mojado"] = "316SS"
    if "API 675" in t: kv["api_675"] = "true"

    return kv


def kv_from_table_cells(table_rows: List[List[str]]) -> Dict[str, str]:
    """Convierte tabla en texto y aplica regex de kv_from_text_page"""
    lines = []
    for row in table_rows:
        cells = [c.strip() for c in row if c]
        if any(cells):
            lines.append(" | ".join(cells))
    table_text = "\n".join(lines)
    return kv_from_text_page(table_text)

# %%
# --- Paso 2: extracción de contenido del PDF ---
import json
from typing import List

def kv_from_text_page(text: str) -> dict:
    """
    Extrae pares clave-valor típicos de una Hoja de Datos desde texto plano (ES/EN).
    Usa regex para capturar caudal, presión, HP, materiales, etc.
    """
    t = " ".join(text.split()).upper()
    kv = {}

    # Caudal (GPH o LPH)
    m = re.search(r"(\d+(?:[.,]\d+)?)\s*(GPH|GALLON[S]?\s+PER\s+HOUR)", t)
    if m: kv["caudal_gph"] = m.group(1)

    m = re.search(r"(\d+(?:[.,]\d+)?)\s*(LPH|LITROS?\s+POR\s+HORA)", t)
    if m: kv["caudal_lph"] = m.group(1)

    # Presión (PSI o BAR)
    m = re.search(r"(\d+(?:[.,]\d+)?)\s*PSI", t)
    if m: kv["presion_psig"] = m.group(1)

    m = re.search(r"(\d+(?:[.,]\d+)?)\s*BAR", t)
    if m: kv["presion_bar"] = m.group(1)

    # Potencia (HP o KW)
    m = re.search(r"(\d+(?:[.,]\d+)?)\s*HP", t)
    if m: kv["hp_motor"] = m.group(1)

    m = re.search(r"(\d+(?:[.,]\d+)?)\s*KW", t)
    if m: kv["kw_motor"] = m.group(1)

    # Viscosidad (cps)
    m = re.search(r"(\d+)\s*-\s*(\d+)\s*CPS", t)
    if m:
        kv["rango_cps_min"] = m.group(1)
        kv["rango_cps_max"] = m.group(2)

    # Bombas operativas + respaldo (ej. "1+1")
    m = re.search(r"\b(\d+)\s*\+\s*(\d+)\b", t)
    if m:
        kv["bombas_operativas"] = m.group(1)
        kv["bombas_respaldo"] = m.group(2)

    # Materiales comunes
    if "304" in t: kv["material_tanque"] = "304SS"
    if "316" in t: kv["material_mojado"] = "316SS"

    # API 675
    if "API 675" in t: kv["api_675"] = "true"

    return kv


def extract_pdf_content(filepath: str) -> List[Document]:
    """
    Extrae texto y tablas del PDF con metadatos enriquecidos:
    - tipo (text/table)
    - prioridad (hoja_datos, alcance, requisito, norma, general)
    - kv cuando se detecta info técnica
    """
    docs: List[Document] = []

    with pdfplumber.open(filepath) as pdf:
        for i, page in enumerate(pdf.pages, start=1):
            # --- Texto plano ---
            txt = page.extract_text() or ""
            clean = clean_text(txt)

            if clean:
                prio = detect_priority(clean)
                md = {"source": filepath, "page": i, "type": "text", "prio": prio}

                kv = kv_from_text_page(clean)
                if kv:
                    md["kv"] = json.dumps(kv, ensure_ascii=False)
                docs.append(Document(page_content=clean, metadata=md))

            # --- Tablas ---
            try:
                tables = page.extract_tables() or []
            except Exception:
                tables = []

            for trows in tables:
                table_text, kv_table = table_to_text_and_kv(trows)
                table_text = clean_text(table_text)
                if not table_text:
                    continue

                prio = detect_priority(table_text)
                md = {"source": filepath, "page": i, "type": "table", "prio": prio}

                kv_detected = kv_from_text_page(table_text)  # también extraemos de texto de tabla
                if kv_table:
                    kv_detected = {**kv_detected, **kv_table}

                if kv_detected:
                    md["kv"] = json.dumps(kv_detected, ensure_ascii=False)

                docs.append(Document(page_content=table_text, metadata=md))

    return docs

# %%
# ============================================
# Paso 3 - Extractor de PDF (texto + tablas + HD + prioridades)
# ============================================
import pdfplumber, json
from langchain.schema import Document
from typing import List

def extract_pdf_content(filepath: str) -> List[Document]:
    docs: List[Document] = []
    
    with pdfplumber.open(filepath) as pdf:
        for i, page in enumerate(pdf.pages, start=1):
            # --- 1) Texto plano ---
            raw_text = page.extract_text() or ""
            clean = clean_text(raw_text)
            if clean:
                md = {
                    "source": filepath,
                    "page": i,
                    "type": "text",
                    "prio": detect_priority(clean)  # prioridad automática
                }

                # Regex: intentar extraer posibles valores técnicos (caudal, presión, hp…)
                kv_text = kv_from_text_page(clean)
                if kv_text:
                    md["kv"] = json.dumps(kv_text, ensure_ascii=False)

                docs.append(Document(page_content=clean, metadata=md))

            # --- 2) Tablas ---
            try:
                tables = page.extract_tables()
            except Exception:
                tables = []

            for t in tables:
                if not t:
                    continue

                table_text = "\n".join(
                    [" | ".join(filter(None, row)) for row in t if any(row)]
                )
                table_text = clean_text(table_text)

                md = {
                    "source": filepath,
                    "page": i,
                    "type": "table",
                    "prio": detect_priority(table_text)
                }

                # Extraer key-values si la tabla tiene estructura tipo HD
                kv_table = kv_from_table_cells(t)
                if kv_table:
                    md["kv"] = json.dumps(kv_table, ensure_ascii=False)

                if table_text:
                    docs.append(Document(page_content=table_text, metadata=md))

    return docs

# %%
# ============================================
# Paso 4 - Indexar en Chroma (persistente)
# ============================================
from collections import Counter
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings

# Configuración global
VDB_PATH = "./vectordb"
COLLECTION_NAME = "autoselx_docs"

def reset_collection():
    """Elimina la colección persistente (para recargar desde cero)."""
    import shutil, os
    if os.path.exists(VDB_PATH):
        shutil.rmtree(VDB_PATH)
        print(f"🗑️ Colección eliminada en {VDB_PATH}")

def add_files_to_vectordb(filepath: str, reset: bool = False):
    if reset:
        reset_collection()

    # --- 1) Extraer documentos brutos (texto + tablas + HD) ---
    raw_docs = extract_pdf_content(filepath)

    # --- 2) Chunking con preservación de prio + kv ---
    splits = chunk_documents(raw_docs)

    # --- 3) Indexar en Chroma persistente ---
    vectorstore = Chroma.from_documents(
        documents=splits,
        embedding=OpenAIEmbeddings(),
        persist_directory=VDB_PATH,
        collection_name=COLLECTION_NAME
    )

    # --- 4) Diagnóstico de indexación ---
    by_type = Counter(d.metadata.get("type", "text") for d in splits)
    by_prio = Counter(d.metadata.get("prio", "general") for d in splits)
    total_kv = sum(1 for d in splits if "kv" in d.metadata)

    print(f"✅ {len(splits)} fragmentos indexados en {VDB_PATH} (colección '{COLLECTION_NAME}')")
    print("   📊 Por tipo:", dict(by_type))
    print("   📊 Por prioridad:", dict(by_prio))
    print(f"   🔑 Documentos con KV extraídos: {total_kv}")

    return vectorstore

# %%
# ============================================
# Paso 5 - Utilidad para inspeccionar fuentes en la colección
# ============================================
from collections import Counter
import chromadb

def get_unique_sources_list():
    """Devuelve lista de fuentes únicas indexadas y estadísticas de metadatos."""
    client = chromadb.PersistentClient(path=VDB_PATH)
    collection = client.get_collection(COLLECTION_NAME)

    data = collection.get(include=["documents", "metadatas"])
    metadatas = data.get("metadatas", [])

    sources = []
    for m in metadatas:
        if not m:
            continue
        src = m.get("source")
        if src:
            sources.append(src.split("/")[-1])

    # 📊 Diagnóstico
    by_prio = Counter(m.get("prio", "general") for m in metadatas if m)
    by_type = Counter(m.get("type", "text") for m in metadatas if m)

    print(f"📁 Fuentes únicas en la colección ({COLLECTION_NAME}): {len(set(sources))}")
    print("   ", sorted(set(sources)))
    print("   📊 Distribución por prioridad:", dict(by_prio))
    print("   📊 Distribución por tipo:", dict(by_type))

    return sorted(set(sources))

# Ejemplo:
# fuentes = get_unique_sources_list()
# print("Fuentes disponibles:", fuentes)

# %%
# ============================================
# Paso 5.1 - Chunking con preservación de metadatos
# ============================================
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.schema import Document

def chunk_documents(docs: List[Document], chunk_size: int = 800, chunk_overlap: int = 100) -> List[Document]:
    """
    Divide documentos largos en chunks manejables para embeddings,
    conservando metadatos (source, page, type, prio, kv).
    """
    splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        separators=["\n\n", "\n", " ", ""]
    )

    chunks: List[Document] = []

    for doc in docs:
        splits = splitter.split_text(doc.page_content)
        for idx, chunk in enumerate(splits, start=1):
            new_meta = doc.metadata.copy()
            new_meta["chunk_id"] = f"{new_meta.get('page','na')}_{idx}"

            # Mantener prio y kv
            if "prio" not in new_meta:
                new_meta["prio"] = "general"
            if "kv" in doc.metadata:
                new_meta["kv"] = doc.metadata["kv"]

            chunks.append(Document(page_content=chunk, metadata=new_meta))

    return chunks

# %%
# --- Paso 6: correr el pipeline ---
if __name__ == "__main__":
    # Limpia todo si quieres partir desde cero:
    # reset_collection()

    vectorstore = add_files_to_vectordb(
        "./data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf",
        reset=False  # pon True si quieres borrar la colección antes
    )
# Out:
# ✅ 613 fragmentos indexados en ./vectordb (colección 'autoselx_docs')
#    📊 Por tipo: {'text': 386, 'table': 227}
#    📊 Por prioridad: {'alcance': 108, 'norma': 80, 'general': 125, 'hoja_datos': 197, 'requisito': 103}
#    🔑 Documentos con KV extraídos: 151

# %%
# ============================================
# Paso 7 - Debug: explorar fragmentos
# ============================================
import json

retriever = vectorstore.as_retriever(search_kwargs={"k": 5})
query = "¿Cuál es el alcance del suministro?"
results = retriever.get_relevant_documents(query)

print(f"🔎 Consulta: {query}")
print(f"📊 Fragmentos recuperados: {len(results)}")

for idx, r in enumerate(results, start=1):
    print(f"\n--- CHUNK {idx} ---")
    print(r.page_content[:500], "...")
    print("Metadatos:", r.metadata)
    if "kv" in r.metadata:
        try:
            kv_dict = json.loads(r.metadata["kv"])
            print("KV dict:", json.dumps(kv_dict, indent=2, ensure_ascii=False))
        except Exception:
            print("KV (raw):", r.metadata["kv"])
# Out:
# /tmp/ipykernel_34383/2361241895.py:8: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   results = retriever.get_relevant_documents(query)
# 🔎 Consulta: ¿Cuál es el alcance del suministro?
# 📊 Fragmentos recuperados: 5
#
# --- CHUNK 1 ---
# SECCIÓN | DESCRIPCIÓN
# 2 | ALCANCE DEL SUMINISTRO
# 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN) ...
# Metadatos: {'type': 'table', 'chunk_id': '1_1', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'alcance', 'page': 1}
#
# --- CHUNK 2 ---
# SECCIÓN | DESCRIPCIÓN
# 2 | ALCANCE DEL SUMINISTRO
# 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN) ...
# Metadatos: {'chunk_id': '1_1', 'page': 1, 'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'alcance'}
#
# --- CHUNK 3 ---
# SECCIÓN | DESCRIPCIÓN
# 2 | ALCANCE DEL SUMINISTRO
# 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN) ...
# Metadatos: {'page': 1, 'chunk_id': '1_1', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'table', 'prio': 'alcance'}
#
# --- CHUNK 4 ---
# SECCIÓN | DESCRIPCIÓN
# 2 | ALCANCE DEL SUMINISTRO
# 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN) ...
# Metadatos: {'page': 1, 'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'alcance', 'chunk_id': '1_1'}
#
# --- CHUNK 5 ---
# SECCIÓN | DESCRIPCIÓN
# 2 | ALCANCE DEL SUMINISTRO
# 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN) ...
# Metadatos: {'page': 1, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'table', 'prio': 'alcance', 'chunk_id': '1_1'}

# %%
# ==========================
# Complemento Paso 7 - Función auxiliar de debug
# ==========================
def debug_query(vectorstore, query, prio=None, k=5):
    """
    Ejecuta una búsqueda con filtro de metadatos (cuando prio != None).
    Hace fallback si no hay resultados en la prioridad especificada.
    """
    import json

    # Mapeo de "prios aceptables" por intención (fallbacks):
    prio_fallbacks = {
        "alcance":   ["alcance", "general"],
        "requisito": ["requisito", "hoja_datos", "general"],
        "norma":     ["norma", "general"],
        "hoja_datos":["hoja_datos", "requisito", "general"]
    }

    print(f"\n🔎 DEBUG QUERY: '{query}' (prio={prio})\n")

    def run_search(allowed_prios, topk):
        if allowed_prios is None:
            # sin filtro
            return vectorstore.similarity_search(query, k=topk)
        else:
            # filtro por metadatos (Chroma soporta {'$in': [...]})
            return vectorstore.similarity_search(
                query, k=topk, filter={"prio": {"$in": allowed_prios}}
            )

    # 1) Intento con filtro (si prio se pidió)
    if prio:
        allowed = prio_fallbacks.get(prio, [prio])
        docs = run_search(allowed_prios=allowed, topk=max(k, 10))
        if not docs:
            # 2) Fallback agresivo: ampliar K y permitir 'general' siempre
            allowed_wide = list(set(allowed + ["general"]))
            docs = run_search(allowed_prios=allowed_wide, topk=50)
            if not docs:
                print("⚠️ No se encontraron resultados con esa prioridad (ni con fallback).")
                return
    else:
        docs = run_search(allowed_prios=None, topk=k)

    print(f"📊 Fragmentos recuperados: {len(docs)}\n")
    for i, r in enumerate(docs, 1):
        print(f"--- CHUNK {i} ---")
        print(r.page_content[:400].replace("\n", " "))
        print("Metadatos:", r.metadata)
        if "kv" in r.metadata:
            try:
                print("KV dict:", json.loads(r.metadata["kv"]))
            except Exception:
                print("KV (raw):", r.metadata["kv"])
        print()

# %%
# ==========================
# Pruebas de debug por prioridad
# ==========================

# Alcance del suministro
debug_query(vectorstore, "alcance del suministro", prio="alcance")
# Out:
# 🔎 DEBUG QUERY: 'alcance del suministro' (prio=alcance)
#
# 📊 Fragmentos recuperados: 10
#
# --- CHUNK 1 ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'alcance', 'type': 'table', 'chunk_id': '1_1', 'page': 1}
#
# --- CHUNK 2 ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'prio': 'alcance', 'page': 1, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'table', 'chunk_id': '1_1'}
#
# --- CHUNK 3 ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '1_1', 'prio': 'alcance', 'page': 1}
#
# --- CHUNK 4 ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'prio': 'alcance', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'table', 'chunk_id': '1_1', 'page': 1}
#
# --- CHUNK 5 ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'page': 1, 'type': 'table', 'prio': 'alcance', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '1_1'}
#
# --- CHUNK 6 ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'page': 1, 'prio': 'alcance', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'table', 'kv': '{"SECCIÓN": "DESCRIPCIÓN", "2": "ALCANCE DEL SUMINISTRO", "10.3": "DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)"}', 'chunk_id': '1_1'}
# KV dict: {'SECCIÓN': 'DESCRIPCIÓN', '2': 'ALCANCE DEL SUMINISTRO', '10.3': 'DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)'}
#
# --- CHUNK 7 ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'prio': 'alcance', 'page': 1, 'type': 'table', 'chunk_id': '1_1', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}
#
# --- CHUNK 8 ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'prio': 'alcance', 'chunk_id': '1_1', 'type': 'table', 'page': 1, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}
#
# --- CHUNK 9 ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'chunk_id': '1_1', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 1, 'prio': 'alcance', 'type': 'table'}
#
# --- CHUNK 10 ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'prio': 'alcance', 'chunk_id': '1_1', 'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 1}

# %%
debug_query(vectorstore, "API 675 caudal presión material", prio="hoja_datos")
# Out:
# 🔎 DEBUG QUERY: 'API 675 caudal presión material' (prio=hoja_datos)
#
# 📊 Fragmentos recuperados: 10
#
# --- CHUNK 1 ---
# UNIDAD COMPLETA      CERTIFICADOS DE MATERIAL APLICADO A UNIDAD PAQUETE OTROS: API 675 BOMBAS DE DESPLAZAMIENTO POSITIVO - VOL. CONTROLADO  OTROS: | | | | | | | | | | | | | | | | | | | |   | PREPARACIÓN DE ENVÍO | | | | | | | | | | | | | | | | | | | |   | PREPARACIÓN DOMÉSTICA:  POR PROVEEDOR  POR COMPRADOR  OBSERVACIONES CAJA DE EXPORTACIÓN:  POR PROVEEDOR  POR COMPRADOR  OBSERVACIONE
# Metadatos: {'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'hoja_datos', 'type': 'table', 'chunk_id': '42_11', 'page': 42, 'kv': '{"caudal_gph": "12-18", "presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "rango_cps_min": "500", "rango_cps_max": "1000", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}'}
# KV dict: {'caudal_gph': '12-18', 'presion_psig': '40', 'hp_motor': '1', 'kw_motor': '5', 'rango_cps_min': '500', 'rango_cps_max': '1000', 'bombas_operativas': '1', 'bombas_respaldo': '1', 'material_tanque': '304SS', 'material_mojado': '316SS', 'api_675': 'true'}
#
# --- CHUNK 2 ---
# VICEPRESIDENCIA DE INGENIERÍA Y PROYECTOS CÓDIGO Elaborado Versión: 1 EDP-F-046 20/11/2017 MR #: INGENIERÍA DETALLADA ESTACIONES MÓDULO CAS-09991-MER-MR- REV: 4 INTEGRAL 000003 Documento: Requisición de Materiales FECHA: Especialidad Mecánica Paquete de inyección de 14/11/2024 químicos • Código de diseño y fecha de vigencia. • Presión de operación y diseño. (Si aplica). • Temperatura de operación
# Metadatos: {'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 21, 'type': 'text', 'chunk_id': '21_2', 'prio': 'hoja_datos'}
#
# --- CHUNK 3 ---
# VICEPRESIDENCIA DE INGENIERÍA Y PROYECTOS CÓDIGO Elaborado Versión: 1 EDP-F-046 20/11/2017 MR #: INGENIERÍA DETALLADA ESTACIONES MÓDULO CAS-09991-MER-MR- REV: 4 INTEGRAL 000003 Documento: Requisición de Materiales FECHA: Especialidad Mecánica Paquete de inyección de 14/11/2024 químicos • Código de diseño y fecha de vigencia. • Presión de operación y diseño. (Si aplica). • Temperatura de operación
# Metadatos: {'chunk_id': '21_2', 'type': 'text', 'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 21}
#
# --- CHUNK 4 ---
# VICEPRESIDENCIA DE INGENIERÍA Y PROYECTOS CÓDIGO Elaborado Versión: 1 EDP-F-046 20/11/2017 MR #: INGENIERÍA DETALLADA ESTACIONES MÓDULO CAS-09991-MER-MR- REV: 4 INTEGRAL 000003 Documento: Requisición de Materiales FECHA: Especialidad Mecánica Paquete de inyección de 14/11/2024 químicos • Código de diseño y fecha de vigencia. • Presión de operación y diseño. (Si aplica). • Temperatura de operación
# Metadatos: {'page': 21, 'type': 'text', 'chunk_id': '21_2', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'hoja_datos'}
#
# --- CHUNK 5 ---
# VICEPRESIDENCIA DE INGENIERÍA Y PROYECTOS CÓDIGO Elaborado Versión: 1 EDP-F-046 20/11/2017 MR #: INGENIERÍA DETALLADA ESTACIONES MÓDULO CAS-09991-MER-MR- REV: 4 INTEGRAL 000003 Documento: Requisición de Materiales FECHA: Especialidad Mecánica Paquete de inyección de 14/11/2024 químicos • Código de diseño y fecha de vigencia. • Presión de operación y diseño. (Si aplica). • Temperatura de operación
# Metadatos: {'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '21_2', 'prio': 'hoja_datos', 'page': 21, 'type': 'text'}
#
# --- CHUNK 6 ---
# VICEPRESIDENCIA DE INGENIERÍA Y PROYECTOS CÓDIGO Elaborado Versión: 1 EDP-F-046 20/11/2017 MR #: INGENIERÍA DETALLADA ESTACIONES MÓDULO CAS-09991-MER-MR- REV: 4 INTEGRAL 000003 Documento: Requisición de Materiales FECHA: Especialidad Mecánica Paquete de inyección de 14/11/2024 químicos • Código de diseño y fecha de vigencia. • Presión de operación y diseño. (Si aplica). • Temperatura de operación
# Metadatos: {'prio': 'hoja_datos', 'page': 21, 'chunk_id': '21_2', 'type': 'text', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}
#
# --- CHUNK 7 ---
# VICEPRESIDENCIA DE INGENIERÍA Y PROYECTOS CÓDIGO Elaborado Versión: 1 EDP-F-046 20/11/2017 MR #: INGENIERÍA DETALLADA ESTACIONES MÓDULO CAS-09991-MER-MR- REV: 4 INTEGRAL 000003 Documento: Requisición de Materiales FECHA: Especialidad Mecánica Paquete de inyección de 14/11/2024 químicos • Código de diseño y fecha de vigencia. • Presión de operación y diseño. (Si aplica). • Temperatura de operación
# Metadatos: {'chunk_id': '21_2', 'page': 21, 'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'text'}
#
# --- CHUNK 8 ---
# VICEPRESIDENCIA DE INGENIERÍA Y PROYECTOS CÓDIGO Elaborado Versión: 1 EDP-F-046 20/11/2017 MR #: INGENIERÍA DETALLADA ESTACIONES MÓDULO CAS-09991-MER-MR- REV: 4 INTEGRAL 000003 Documento: Requisición de Materiales FECHA: Especialidad Mecánica Paquete de inyección de 14/11/2024 químicos • Código de diseño y fecha de vigencia. • Presión de operación y diseño. (Si aplica). • Temperatura de operación
# Metadatos: {'chunk_id': '21_2', 'page': 21, 'prio': 'hoja_datos', 'type': 'text', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}
#
# --- CHUNK 9 ---
# VICEPRESIDENCIA DE INGENIERÍA Y PROYECTOS CÓDIGO Elaborado Versión: 1 EDP-F-046 20/11/2017 MR #: INGENIERÍA DETALLADA ESTACIONES MÓDULO CAS-09991-MER-MR- REV: 4 INTEGRAL 000003 Documento: Requisición de Materiales FECHA: Especialidad Mecánica Paquete de inyección de 14/11/2024 químicos • Código de diseño y fecha de vigencia. • Presión de operación y diseño. (Si aplica). • Temperatura de operación
# Metadatos: {'type': 'text', 'prio': 'hoja_datos', 'page': 21, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '21_2'}
#
# --- CHUNK 10 ---
# VICEPRESIDENCIA DE INGENIERÍA Y PROYECTOS CÓDIGO Elaborado Versión: 1 EDP-F-046 20/11/2017 MR #: INGENIERÍA DETALLADA ESTACIONES MÓDULO CAS-09991-MER-MR- REV: 4 INTEGRAL 000003 Documento: Requisición de Materiales FECHA: Especialidad Mecánica Paquete de inyección de 14/11/2024 químicos • Código de diseño y fecha de vigencia. • Presión de operación y diseño. (Si aplica). • Temperatura de operación
# Metadatos: {'page': 21, 'type': 'text', 'chunk_id': '21_2', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'hoja_datos'}

# %%
debug_query(vectorstore, "RETIE y normas aplicables", prio="norma")
# Out:
# 🔎 DEBUG QUERY: 'RETIE y normas aplicables' (prio=norma)
#
# 📊 Fragmentos recuperados: 10
#
# --- CHUNK 1 ---
# puede ser hecha sin permiso escrito. Ningún párrafo de esta publicación puede ser reproducido, copiado o transmitido digitalmente sin un consentimiento escrito o de acuerdo con las leyes que regulan los derechos de autor y con base en la regulación vigente.
# Metadatos: {'prio': 'norma', 'type': 'text', 'page': 4, 'chunk_id': '4_4', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}
#
# --- CHUNK 2 ---
# puede ser hecha sin permiso escrito. Ningún párrafo de esta publicación puede ser reproducido, copiado o transmitido digitalmente sin un consentimiento escrito o de acuerdo con las leyes que regulan los derechos de autor y con base en la regulación vigente.
# Metadatos: {'page': 14, 'type': 'text', 'prio': 'norma', 'chunk_id': '14_5', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}
#
# --- CHUNK 3 ---
# puede ser hecha sin permiso escrito. Ningún párrafo de esta publicación puede ser reproducido, copiado o transmitido digitalmente sin un consentimiento escrito o de acuerdo con las leyes que regulan los derechos de autor y con base en la regulación vigente.
# Metadatos: {'page': 15, 'prio': 'norma', 'chunk_id': '15_5', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'text'}
#
# --- CHUNK 4 ---
# puede ser hecha sin permiso escrito. Ningún párrafo de esta publicación puede ser reproducido, copiado o transmitido digitalmente sin un consentimiento escrito o de acuerdo con las leyes que regulan los derechos de autor y con base en la regulación vigente.
# Metadatos: {'prio': 'norma', 'page': 4, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'text', 'chunk_id': '4_4'}
#
# --- CHUNK 5 ---
# puede ser hecha sin permiso escrito. Ningún párrafo de esta publicación puede ser reproducido, copiado o transmitido digitalmente sin un consentimiento escrito o de acuerdo con las leyes que regulan los derechos de autor y con base en la regulación vigente.
# Metadatos: {'type': 'text', 'page': 15, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'norma', 'chunk_id': '15_5'}
#
# --- CHUNK 6 ---
# puede ser hecha sin permiso escrito. Ningún párrafo de esta publicación puede ser reproducido, copiado o transmitido digitalmente sin un consentimiento escrito o de acuerdo con las leyes que regulan los derechos de autor y con base en la regulación vigente.
# Metadatos: {'page': 29, 'prio': 'norma', 'chunk_id': '29_5', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'text'}
#
# --- CHUNK 7 ---
# puede ser hecha sin permiso escrito. Ningún párrafo de esta publicación puede ser reproducido, copiado o transmitido digitalmente sin un consentimiento escrito o de acuerdo con las leyes que regulan los derechos de autor y con base en la regulación vigente.
# Metadatos: {'page': 4, 'type': 'text', 'prio': 'norma', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '4_4'}
#
# --- CHUNK 8 ---
# puede ser hecha sin permiso escrito. Ningún párrafo de esta publicación puede ser reproducido, copiado o transmitido digitalmente sin un consentimiento escrito o de acuerdo con las leyes que regulan los derechos de autor y con base en la regulación vigente.
# Metadatos: {'prio': 'norma', 'chunk_id': '14_5', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'text', 'page': 14}
#
# --- CHUNK 9 ---
# puede ser hecha sin permiso escrito. Ningún párrafo de esta publicación puede ser reproducido, copiado o transmitido digitalmente sin un consentimiento escrito o de acuerdo con las leyes que regulan los derechos de autor y con base en la regulación vigente.
# Metadatos: {'page': 29, 'prio': 'norma', 'chunk_id': '29_5', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'text'}
#
# --- CHUNK 10 ---
# puede ser hecha sin permiso escrito. Ningún párrafo de esta publicación puede ser reproducido, copiado o transmitido digitalmente sin un consentimiento escrito o de acuerdo con las leyes que regulan los derechos de autor y con base en la regulación vigente.
# Metadatos: {'chunk_id': '12_6', 'type': 'text', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 12, 'prio': 'norma'}

# %%
debug_query(vectorstore, "requisitos técnicos del sistema de dosificación", prio="requisito")
# Out:
# 🔎 DEBUG QUERY: 'requisitos técnicos del sistema de dosificación' (prio=requisito)
#
# 📊 Fragmentos recuperados: 10
#
# --- CHUNK 1 ---
# de acuerdo con la hoja de datos Paquete De Química STAP EC3 CAS-09991-MER-HD-000003 a fin de garantizar una unidad funcional completa. El PROVEEDOR debe cumplir con los requerimientos mínimos requeridos por el cliente para entregar un sistema de dosificación efectivo y que cumpla con las expectativas en la operación y producción de la estación. EDP-F-046 – 20/11/2017 V-1 8/36 Documento Rector: EDP
# Metadatos: {'page': 8, 'prio': 'hoja_datos', 'chunk_id': '8_5', 'type': 'text', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}
#
# --- CHUNK 2 ---
# de acuerdo con la hoja de datos Paquete De Química STAP EC3 CAS-09991-MER-HD-000003 a fin de garantizar una unidad funcional completa. El PROVEEDOR debe cumplir con los requerimientos mínimos requeridos por el cliente para entregar un sistema de dosificación efectivo y que cumpla con las expectativas en la operación y producción de la estación. EDP-F-046 – 20/11/2017 V-1 8/36 Documento Rector: EDP
# Metadatos: {'chunk_id': '8_5', 'type': 'text', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'hoja_datos', 'page': 8}
#
# --- CHUNK 3 ---
# de acuerdo con la hoja de datos Paquete De Química STAP EC3 CAS-09991-MER-HD-000003 a fin de garantizar una unidad funcional completa. El PROVEEDOR debe cumplir con los requerimientos mínimos requeridos por el cliente para entregar un sistema de dosificación efectivo y que cumpla con las expectativas en la operación y producción de la estación. EDP-F-046 – 20/11/2017 V-1 8/36 Documento Rector: EDP
# Metadatos: {'type': 'text', 'page': 8, 'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '8_5'}
#
# --- CHUNK 4 ---
# de acuerdo con la hoja de datos Paquete De Química STAP EC3 CAS-09991-MER-HD-000003 a fin de garantizar una unidad funcional completa. El PROVEEDOR debe cumplir con los requerimientos mínimos requeridos por el cliente para entregar un sistema de dosificación efectivo y que cumpla con las expectativas en la operación y producción de la estación. EDP-F-046 – 20/11/2017 V-1 8/36 Documento Rector: EDP
# Metadatos: {'page': 8, 'chunk_id': '8_5', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'hoja_datos', 'type': 'text'}
#
# --- CHUNK 5 ---
# de acuerdo con la hoja de datos Paquete De Química STAP EC3 CAS-09991-MER-HD-000003 a fin de garantizar una unidad funcional completa. El PROVEEDOR debe cumplir con los requerimientos mínimos requeridos por el cliente para entregar un sistema de dosificación efectivo y que cumpla con las expectativas en la operación y producción de la estación. EDP-F-046 – 20/11/2017 V-1 8/36 Documento Rector: EDP
# Metadatos: {'type': 'text', 'chunk_id': '8_5', 'page': 8, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'hoja_datos'}
#
# --- CHUNK 6 ---
# de acuerdo con la hoja de datos Paquete De Química STAP EC3 CAS-09991-MER-HD-000003 a fin de garantizar una unidad funcional completa. El PROVEEDOR debe cumplir con los requerimientos mínimos requeridos por el cliente para entregar un sistema de dosificación efectivo y que cumpla con las expectativas en la operación y producción de la estación. EDP-F-046 – 20/11/2017 V-1 8/36 Documento Rector: EDP
# Metadatos: {'type': 'text', 'page': 8, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'hoja_datos', 'chunk_id': '8_5'}
#
# --- CHUNK 7 ---
# de acuerdo con la hoja de datos Paquete De Química STAP EC3 CAS-09991-MER-HD-000003 a fin de garantizar una unidad funcional completa. El PROVEEDOR debe cumplir con los requerimientos mínimos requeridos por el cliente para entregar un sistema de dosificación efectivo y que cumpla con las expectativas en la operación y producción de la estación. EDP-F-046 – 20/11/2017 V-1 8/36 Documento Rector: EDP
# Metadatos: {'chunk_id': '8_5', 'page': 8, 'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'text'}
#
# --- CHUNK 8 ---
# de acuerdo con la hoja de datos Paquete De Química STAP EC3 CAS-09991-MER-HD-000003 a fin de garantizar una unidad funcional completa. El PROVEEDOR debe cumplir con los requerimientos mínimos requeridos por el cliente para entregar un sistema de dosificación efectivo y que cumpla con las expectativas en la operación y producción de la estación. EDP-F-046 – 20/11/2017 V-1 8/36 Documento Rector: EDP
# Metadatos: {'page': 8, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'text', 'prio': 'hoja_datos', 'chunk_id': '8_5'}
#
# --- CHUNK 9 ---
# de acuerdo con la hoja de datos Paquete De Química STAP EC3 CAS-09991-MER-HD-000003 a fin de garantizar una unidad funcional completa. El PROVEEDOR debe cumplir con los requerimientos mínimos requeridos por el cliente para entregar un sistema de dosificación efectivo y que cumpla con las expectativas en la operación y producción de la estación. EDP-F-046 – 20/11/2017 V-1 8/36 Documento Rector: EDP
# Metadatos: {'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'text', 'prio': 'hoja_datos', 'chunk_id': '8_5', 'page': 8}
#
# --- CHUNK 10 ---
# de acuerdo con la hoja de datos Paquete De Química STAP EC3 CAS-09991-MER-HD-000003 a fin de garantizar una unidad funcional completa. El PROVEEDOR debe cumplir con los requerimientos mínimos requeridos por el cliente para entregar un sistema de dosificación efectivo y que cumpla con las expectativas en la operación y producción de la estación. EDP-F-046 – 20/11/2017 V-1 8/36 Documento Rector: EDP
# Metadatos: {'prio': 'hoja_datos', 'page': 8, 'type': 'text', 'chunk_id': '8_5', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}

# %%
# ============================================
# Paso 8 - Probar extracción de Hoja de Datos API 675
# ============================================
import json

def buscar_hojas_datos(pregunta: str = "hoja de datos bomba", k: int = 12):
    # --- 1) Buscamos primero chunks con prio=hoja_datos ---
    retriever = vectorstore.as_retriever(search_kwargs={"k": k})
    results = retriever.get_relevant_documents(pregunta)
    hd_chunks = [r for r in results if r.metadata.get("prio") == "hoja_datos"]

    # --- 2) Si hay pocos resultados, ampliamos con los que tengan KV ---
    if len(hd_chunks) < 3:
        kv_chunks = [r for r in results if "kv" in r.metadata]
        filtrados = hd_chunks + kv_chunks
    else:
        filtrados = hd_chunks

    print(f"🔎 Total de chunks candidatos (HD/kv): {len(filtrados)}")

    count = 0
    for r in filtrados:
        has_kv = "kv" in r.metadata
        if has_kv:
            count += 1

        flag = "🔑" if has_kv else ""
        print(f"\n--- CHUNK HD {flag} ---")
        print(f"p.{r.metadata.get('page')} | {r.metadata.get('type')} | prio={r.metadata.get('prio')}")
        print(r.page_content[:400])

        if has_kv:
            try:
                kv = json.loads(r.metadata["kv"])
                print("KV:", kv)
            except Exception:
                print("KV (raw):", r.metadata["kv"])

    print(f"✅ Chunks con KV reales: {count}")
    return filtrados


# Ejemplo:
buscar_hojas_datos("Datos de diseño de bomba dosificadora API 675 (caudal, presión, HP)")
# Out:
# 🔎 Total de chunks candidatos (HD/kv): 12
#
# --- CHUNK HD 🔑 ---
# p.43 | text | prio=hoja_datos
# 96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El
# paquete contara con un sistema de control PLC dedicado a gestionar todas las fun
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | text | prio=hoja_datos
# 96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El
# paquete contara con un sistema de control PLC dedicado a gestionar todas las fun
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | text | prio=hoja_datos
# 96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El
# paquete contara con un sistema de control PLC dedicado a gestionar todas las fun
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | text | prio=hoja_datos
# 96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El
# paquete contara con un sistema de control PLC dedicado a gestionar todas las fun
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | text | prio=hoja_datos
# 96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El
# paquete contara con un sistema de control PLC dedicado a gestionar todas las fun
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | text | prio=hoja_datos
# 96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El
# paquete contara con un sistema de control PLC dedicado a gestionar todas las fun
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | table | prio=hoja_datos
# INGENIERÍA DETALLADA ESTACIONES MÓDULO INTEGRAL
# HOJAS DE DATOS PAQUETE DE QUÍMICO STAP EC3 | CAS-09991-MER-HD-000003
# Documento No.
# Revisión:AFC4
# 82 | PROPUESTA PESOS Y DIMCOENMSPIROANES (NOTA 9) AS BUIT
# 83
# 84 | METI | DESCRIPCIÓN | MODELO | CANTIDAD | PATÍN DE PREPARACIÓN (lbs)
# (con prueba hidrostática) | BOMBAS DE DOSIFICACIÓN (lbs) | TOTAL PATÍN (lbs) | DIMENSIONES PATÍN DE PREPARACIÓN
# (L x A x
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | table | prio=hoja_datos
# INGENIERÍA DETALLADA ESTACIONES MÓDULO INTEGRAL
# HOJAS DE DATOS PAQUETE DE QUÍMICO STAP EC3 | CAS-09991-MER-HD-000003
# Documento No.
# Revisión:AFC4
# 82 | PROPUESTA PESOS Y DIMCOENMSPIROANES (NOTA 9) AS BUIT
# 83
# 84 | METI | DESCRIPCIÓN | MODELO | CANTIDAD | PATÍN DE PREPARACIÓN (lbs)
# (con prueba hidrostática) | BOMBAS DE DOSIFICACIÓN (lbs) | TOTAL PATÍN (lbs) | DIMENSIONES PATÍN DE PREPARACIÓN
# (L x A x
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | table | prio=hoja_datos
# INGENIERÍA DETALLADA ESTACIONES MÓDULO INTEGRAL
# HOJAS DE DATOS PAQUETE DE QUÍMICO STAP EC3 | CAS-09991-MER-HD-000003
# Documento No.
# Revisión:AFC4
# 82 | PROPUESTA PESOS Y DIMCOENMSPIROANES (NOTA 9) AS BUIT
# 83
# 84 | METI | DESCRIPCIÓN | MODELO | CANTIDAD | PATÍN DE PREPARACIÓN (lbs)
# (con prueba hidrostática) | BOMBAS DE DOSIFICACIÓN (lbs) | TOTAL PATÍN (lbs) | DIMENSIONES PATÍN DE PREPARACIÓN
# (L x A x
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | table | prio=hoja_datos
# INGENIERÍA DETALLADA ESTACIONES MÓDULO INTEGRAL
# HOJAS DE DATOS PAQUETE DE QUÍMICO STAP EC3 | CAS-09991-MER-HD-000003
# Documento No.
# Revisión:AFC4
# 82 | PROPUESTA PESOS Y DIMCOENMSPIROANES (NOTA 9) AS BUIT
# 83
# 84 | METI | DESCRIPCIÓN | MODELO | CANTIDAD | PATÍN DE PREPARACIÓN (lbs)
# (con prueba hidrostática) | BOMBAS DE DOSIFICACIÓN (lbs) | TOTAL PATÍN (lbs) | DIMENSIONES PATÍN DE PREPARACIÓN
# (L x A x
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | table | prio=hoja_datos
# INGENIERÍA DETALLADA ESTACIONES MÓDULO INTEGRAL
# HOJAS DE DATOS PAQUETE DE QUÍMICO STAP EC3 | CAS-09991-MER-HD-000003
# Documento No.
# Revisión:AFC4
# 82 | PROPUESTA PESOS Y DIMCOENMSPIROANES (NOTA 9) AS BUIT
# 83
# 84 | METI | DESCRIPCIÓN | MODELO | CANTIDAD | PATÍN DE PREPARACIÓN (lbs)
# (con prueba hidrostática) | BOMBAS DE DOSIFICACIÓN (lbs) | TOTAL PATÍN (lbs) | DIMENSIONES PATÍN DE PREPARACIÓN
# (L x A x
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | table | prio=hoja_datos
# INGENIERÍA DETALLADA ESTACIONES MÓDULO INTEGRAL
# HOJAS DE DATOS PAQUETE DE QUÍMICO STAP EC3 | CAS-09991-MER-HD-000003
# Documento No.
# Revisión:AFC4
# 82 | PROPUESTA PESOS Y DIMCOENMSPIROANES (NOTA 9) AS BUIT
# 83
# 84 | METI | DESCRIPCIÓN | MODELO | CANTIDAD | PATÍN DE PREPARACIÓN (lbs)
# (con prueba hidrostática) | BOMBAS DE DOSIFICACIÓN (lbs) | TOTAL PATÍN (lbs) | DIMENSIONES PATÍN DE PREPARACIÓN
# (L x A x
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
# ✅ Chunks con KV reales: 12
# [Document(metadata={'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'type': 'text', 'chunk_id': '43_3', 'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 43}, page_content='96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El\npaquete contara con un sistema de control PLC dedicado a gestionar todas las funciones del paquete, sus cajas (Potencia, Instrumentación, Instrumentos y Control NEMA 4X (Área no clasificada). La instrumentación mínima asociada al paquete está indicada en el P&ID CAS-09991-PRO-PID-000012 - STAP EC3.\n97'),
#  Document(metadata={'type': 'text', 'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '43_3', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'page': 43}, page_content='96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El\npaquete contara con un sistema de control PLC dedicado a gestionar todas las funciones del paquete, sus cajas (Potencia, Instrumentación, Instrumentos y Control NEMA 4X (Área no clasificada). La instrumentación mínima asociada al paquete está indicada en el P&ID CAS-09991-PRO-PID-000012 - STAP EC3.\n97'),
#  Document(metadata={'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'chunk_id': '43_3', 'page': 43, 'type': 'text', 'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}, page_content='96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El\npaquete contara con un sistema de control PLC dedicado a gestionar todas las funciones del paquete, sus cajas (Potencia, Instrumentación, Instrumentos y Control NEMA 4X (Área no clasificada). La instrumentación mínima asociada al paquete está indicada en el P&ID CAS-09991-PRO-PID-000012 - STAP EC3.\n97'),
#  Document(metadata={'type': 'text', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'chunk_id': '43_3', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 43, 'prio': 'hoja_datos'}, page_content='96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El\npaquete contara con un sistema de control PLC dedicado a gestionar todas las funciones del paquete, sus cajas (Potencia, Instrumentación, Instrumentos y Control NEMA 4X (Área no clasificada). La instrumentación mínima asociada al paquete está indicada en el P&ID CAS-09991-PRO-PID-000012 - STAP EC3.\n97'),
#  Document(metadata={'type': 'text', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '43_3', 'prio': 'hoja_datos', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'page': 43}, page_content='96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El\npaquete contara con un sistema de control PLC dedicado a gestionar todas las funciones del paquete, sus cajas (Potencia, Instrumentación, Instrumentos y Control NEMA 4X (Área no clasificada). La instrumentación mínima asociada al paquete está indicada en el P&ID CAS-09991-PRO-PID-000012 - STAP EC3.\n97'),
#  Document(metadata={'type': 'text', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '43_3', 'page': 43}, page_content='96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El\npaquete contara con un sistema de control PLC dedicado a gestionar todas las funciones del paquete, sus cajas (Potencia, Instrumentación, Instrumentos y Control NEMA 4X (Área no clasificada). La instrumentación mínima asociada al paquete está indicada en el P&ID CAS-09991-PRO-PID-000012 - STAP EC3.\n97'),
#  Document(metadata={'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'hoja_datos', 'chunk_id': '43_1', 'page': 43, 'type': 'table', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}'}, page_content='INGENIERÍA DETALLADA ESTACIONES MÓDULO INTEGRAL\nHOJAS DE DATOS PAQUETE DE QUÍMICO STAP EC3 | CAS-09991-MER-HD-000003\nDocumento No.\nRevisión:AFC4\n82 | PROPUESTA PESOS Y DIMCOENMSPIROANES (NOTA 9) AS BUIT\n83\n84 | METI | DESCRIPCIÓN | MODELO | CANTIDAD | PATÍN DE PREPARACIÓN (lbs)\n(con prueba hidrostática) | BOMBAS DE DOSIFICACIÓN (lbs) | TOTAL PATÍN (lbs) | DIMENSIONES PATÍN DE PREPARACIÓN\n(L x A x H) in | DIMENSIONES\nTOTAL PATÍN\n(con bombas de dosificación)\n(L x A x H) in\n85\n86 | 1 | PATÍN DE PREPARCION Y DOSIFICACION | PROVEEDOR | 1 | 11133 LBS | 500 LBS | 11633 LBS | 130 x 80 x 90 | 190 x 90 x 100\n87\n88\n89 | REQUERIMIENTOS DE SERVICIO\n90'),
#  Document(metadata={'prio': 'hoja_datos', 'chunk_id': '43_1', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'type': 'table', 'page': 43}, page_content='INGENIERÍA DETALLADA ESTACIONES MÓDULO INTEGRAL\nHOJAS DE DATOS PAQUETE DE QUÍMICO STAP EC3 | CAS-09991-MER-HD-000003\nDocumento No.\nRevisión:AFC4\n82 | PROPUESTA PESOS Y DIMCOENMSPIROANES (NOTA 9) AS BUIT\n83\n84 | METI | DESCRIPCIÓN | MODELO | CANTIDAD | PATÍN DE PREPARACIÓN (lbs)\n(con prueba hidrostática) | BOMBAS DE DOSIFICACIÓN (lbs) | TOTAL PATÍN (lbs) | DIMENSIONES PATÍN DE PREPARACIÓN\n(L x A x H) in | DIMENSIONES\nTOTAL PATÍN\n(con bombas de dosificación)\n(L x A x H) in\n85\n86 | 1 | PATÍN DE PREPARCION Y DOSIFICACION | PROVEEDOR | 1 | 11133 LBS | 500 LBS | 11633 LBS | 130 x 80 x 90 | 190 x 90 x 100\n87\n88\n89 | REQUERIMIENTOS DE SERVICIO\n90'),
#  Document(metadata={'type': 'table', 'page': 43, 'prio': 'hoja_datos', 'chunk_id': '43_1', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}'}, page_content='INGENIERÍA DETALLADA ESTACIONES MÓDULO INTEGRAL\nHOJAS DE DATOS PAQUETE DE QUÍMICO STAP EC3 | CAS-09991-MER-HD-000003\nDocumento No.\nRevisión:AFC4\n82 | PROPUESTA PESOS Y DIMCOENMSPIROANES (NOTA 9) AS BUIT\n83\n84 | METI | DESCRIPCIÓN | MODELO | CANTIDAD | PATÍN DE PREPARACIÓN (lbs)\n(con prueba hidrostática) | BOMBAS DE DOSIFICACIÓN (lbs) | TOTAL PATÍN (lbs) | DIMENSIONES PATÍN DE PREPARACIÓN\n(L x A x H) in | DIMENSIONES\nTOTAL PATÍN\n(con bombas de dosificación)\n(L x A x H) in\n85\n86 | 1 | PATÍN DE PREPARCION Y DOSIFICACION | PROVEEDOR | 1 | 11133 LBS | 500 LBS | 11633 LBS | 130 x 80 x 90 | 190 x 90 x 100\n87\n88\n89 | REQUERIMIENTOS DE SERVICIO\n90'),
#  Document(metadata={'page': 43, 'prio': 'hoja_datos', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'chunk_id': '43_1', 'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}, page_content='INGENIERÍA DETALLADA ESTACIONES MÓDULO INTEGRAL\nHOJAS DE DATOS PAQUETE DE QUÍMICO STAP EC3 | CAS-09991-MER-HD-000003\nDocumento No.\nRevisión:AFC4\n82 | PROPUESTA PESOS Y DIMCOENMSPIROANES (NOTA 9) AS BUIT\n83\n84 | METI | DESCRIPCIÓN | MODELO | CANTIDAD | PATÍN DE PREPARACIÓN (lbs)\n(con prueba hidrostática) | BOMBAS DE DOSIFICACIÓN (lbs) | TOTAL PATÍN (lbs) | DIMENSIONES PATÍN DE PREPARACIÓN\n(L x A x H) in | DIMENSIONES\nTOTAL PATÍN\n(con bombas de dosificación)\n(L x A x H) in\n85\n86 | 1 | PATÍN DE PREPARCION Y DOSIFICACION | PROVEEDOR | 1 | 11133 LBS | 500 LBS | 11633 LBS | 130 x 80 x 90 | 190 x 90 x 100\n87\n88\n89 | REQUERIMIENTOS DE SERVICIO\n90'),
#  Document(metadata={'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'page': 43, 'chunk_id': '43_1', 'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'table'}, page_content='INGENIERÍA DETALLADA ESTACIONES MÓDULO INTEGRAL\nHOJAS DE DATOS PAQUETE DE QUÍMICO STAP EC3 | CAS-09991-MER-HD-000003\nDocumento No.\nRevisión:AFC4\n82 | PROPUESTA PESOS Y DIMCOENMSPIROANES (NOTA 9) AS BUIT\n83\n84 | METI | DESCRIPCIÓN | MODELO | CANTIDAD | PATÍN DE PREPARACIÓN (lbs)\n(con prueba hidrostática) | BOMBAS DE DOSIFICACIÓN (lbs) | TOTAL PATÍN (lbs) | DIMENSIONES PATÍN DE PREPARACIÓN\n(L x A x H) in | DIMENSIONES\nTOTAL PATÍN\n(con bombas de dosificación)\n(L x A x H) in\n85\n86 | 1 | PATÍN DE PREPARCION Y DOSIFICACION | PROVEEDOR | 1 | 11133 LBS | 500 LBS | 11633 LBS | 130 x 80 x 90 | 190 x 90 x 100\n87\n88\n89 | REQUERIMIENTOS DE SERVICIO\n90'),
#  Document(metadata={'prio': 'hoja_datos', 'page': 43, 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '43_1'}, page_content='INGENIERÍA DETALLADA ESTACIONES MÓDULO INTEGRAL\nHOJAS DE DATOS PAQUETE DE QUÍMICO STAP EC3 | CAS-09991-MER-HD-000003\nDocumento No.\nRevisión:AFC4\n82 | PROPUESTA PESOS Y DIMCOENMSPIROANES (NOTA 9) AS BUIT\n83\n84 | METI | DESCRIPCIÓN | MODELO | CANTIDAD | PATÍN DE PREPARACIÓN (lbs)\n(con prueba hidrostática) | BOMBAS DE DOSIFICACIÓN (lbs) | TOTAL PATÍN (lbs) | DIMENSIONES PATÍN DE PREPARACIÓN\n(L x A x H) in | DIMENSIONES\nTOTAL PATÍN\n(con bombas de dosificación)\n(L x A x H) in\n85\n86 | 1 | PATÍN DE PREPARCION Y DOSIFICACION | PROVEEDOR | 1 | 11133 LBS | 500 LBS | 11633 LBS | 130 x 80 x 90 | 190 x 90 x 100\n87\n88\n89 | REQUERIMIENTOS DE SERVICIO\n90')]

# %%
# ============================================
# Paso 8.1 - Consolidar Hoja de Datos API 675
# ============================================
import json

def extraer_campos_extras(texto: str) -> Dict[str, str]:
    """Regex para campos no capturados aún en kv_from_text_page"""
    t = texto.upper()
    kv = {}

    # Fluido de operación
    m = re.search(r"FLUIDO\s+DE\s+OPERACI[ÓO]N\s+SI\s+([A-ZÁÉÍÓÚ0-9\s]+)", t)
    if m:
        kv["fluido"] = m.group(1).title()

    # Viscosidad cP
    m = re.search(r"VISCO(SIDAD)?[^0-9]*(\d{2,5})\s*-\s*(\d{2,5})\s*CP", t)
    if m:
        kv["viscosidad_cps"] = f"{m.group(2)}-{m.group(3)}"

    # Eficiencia %
    m = re.search(r"EFICIENCIA.*?(\d{1,3})\s*%|≥\s*(\d{1,3})", t)
    if m:
        kv["eficiencia_pct"] = m.group(1) or m.group(2)

    # Clasificación de área
    m = re.search(r"CLASIFICACI[ÓO]N\s+DEL\s+ÁREA\s+NO\s+([A-Z\s]+)", t)
    if m:
        kv["clasificacion_area"] = m.group(1).title()

    return kv

def consolidar_hoja_datos(pregunta="hoja de datos bomba API 675", k=12) -> Dict[str, Any]:
    docs = buscar_hojas_datos(pregunta, k=k)
    consolidado = {}

    for d in docs:
        # 1) KV en metadata
        if "kv" in d.metadata:
            try:
                kv = json.loads(d.metadata["kv"])
                consolidado.update(kv)
            except Exception:
                pass

        # 2) Extra campos con regex sobre el contenido
        extras = extraer_campos_extras(d.page_content)
        consolidado.update(extras)

    print("\n✅ JSON consolidado:")
    print(json.dumps(consolidado, indent=2, ensure_ascii=False))
    return consolidado

# Ejemplo:
consolidar_hoja_datos("Datos de diseño de bomba dosificadora API 675")
# Out:
# 🔎 Total de chunks candidatos (HD/kv): 12
#
# --- CHUNK HD 🔑 ---
# p.43 | text | prio=hoja_datos
# 96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El
# paquete contara con un sistema de control PLC dedicado a gestionar todas las fun
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | text | prio=hoja_datos
# 96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El
# paquete contara con un sistema de control PLC dedicado a gestionar todas las fun
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | text | prio=hoja_datos
# 96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El
# paquete contara con un sistema de control PLC dedicado a gestionar todas las fun
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | text | prio=hoja_datos
# 96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El
# paquete contara con un sistema de control PLC dedicado a gestionar todas las fun
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | text | prio=hoja_datos
# 96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El
# paquete contara con un sistema de control PLC dedicado a gestionar todas las fun
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | text | prio=hoja_datos
# 96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El
# paquete contara con un sistema de control PLC dedicado a gestionar todas las fun
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | text | prio=hoja_datos
# 96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El
# paquete contara con un sistema de control PLC dedicado a gestionar todas las fun
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | text | prio=hoja_datos
# 96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El
# paquete contara con un sistema de control PLC dedicado a gestionar todas las fun
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | text | prio=hoja_datos
# 96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El
# paquete contara con un sistema de control PLC dedicado a gestionar todas las fun
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | text | prio=hoja_datos
# 96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El
# paquete contara con un sistema de control PLC dedicado a gestionar todas las fun
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | text | prio=hoja_datos
# 96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El
# paquete contara con un sistema de control PLC dedicado a gestionar todas las fun
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK HD 🔑 ---
# p.43 | text | prio=hoja_datos
# 96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El
# paquete contara con un sistema de control PLC dedicado a gestionar todas las fun
# KV: {'caudal_gph': '12-18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
# ✅ Chunks con KV reales: 12
#
# ✅ JSON consolidado:
# {
#   "caudal_gph": "12-18",
#   "presion_psig": "100",
#   "hp_motor": "1",
#   "material_tanque": "304SS",
#   "api_675": "true"
# }
# {'caudal_gph': '12-18',
#  'presion_psig': '100',
#  'hp_motor': '1',
#  'material_tanque': '304SS',
#  'api_675': 'true'}

# %%
# ============================================
# Paso 9 - Inspeccionar metadatos del Alcance
# ============================================

def buscar_alcance(pregunta: str = "alcance del suministro", k: int = 8):
    """Busca chunks relacionados con alcance (prio=alcance) y muestra metadatos"""
    retriever = vectorstore.as_retriever(
        search_kwargs={"k": k, "filter": {"prio": "alcance"}}
    )
    results = retriever.get_relevant_documents(pregunta)

    print(f"🔎 Total de chunks recuperados (prio=alcance): {len(results)}")
    for r in results:
        print(
            f"\n--- CHUNK p.{r.metadata.get('page')} | "
            f"{r.metadata.get('type')} | prio={r.metadata.get('prio')} ---"
        )
        print(r.page_content[:400].replace("\n", " "))
        print("Metadatos:", r.metadata)

    return results

# Ejemplo de prueba:
buscar_alcance()
# Out:
# 🔎 Total de chunks recuperados (prio=alcance): 8
#
# --- CHUNK p.1 | table | prio=alcance ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'page': 1, 'chunk_id': '1_1', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'alcance', 'type': 'table'}
#
# --- CHUNK p.1 | table | prio=alcance ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'chunk_id': '1_1', 'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 1, 'prio': 'alcance'}
#
# --- CHUNK p.1 | table | prio=alcance ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '1_1', 'type': 'table', 'prio': 'alcance', 'page': 1}
#
# --- CHUNK p.1 | table | prio=alcance ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'page': 1, 'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '1_1', 'prio': 'alcance'}
#
# --- CHUNK p.1 | table | prio=alcance ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'table', 'prio': 'alcance', 'page': 1, 'chunk_id': '1_1'}
#
# --- CHUNK p.1 | table | prio=alcance ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'prio': 'alcance', 'kv': '{"SECCIÓN": "DESCRIPCIÓN", "2": "ALCANCE DEL SUMINISTRO", "10.3": "DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)"}', 'type': 'table', 'page': 1, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '1_1'}
#
# --- CHUNK p.1 | table | prio=alcance ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'page': 1, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'table', 'prio': 'alcance', 'chunk_id': '1_1'}
#
# --- CHUNK p.1 | table | prio=alcance ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'page': 1, 'prio': 'alcance', 'chunk_id': '1_1', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'table'}
# [Document(metadata={'page': 1, 'chunk_id': '1_1', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'alcance', 'type': 'table'}, page_content='SECCIÓN | DESCRIPCIÓN\n2 | ALCANCE DEL SUMINISTRO\n10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)'),
#  Document(metadata={'chunk_id': '1_1', 'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 1, 'prio': 'alcance'}, page_content='SECCIÓN | DESCRIPCIÓN\n2 | ALCANCE DEL SUMINISTRO\n10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)'),
#  Document(metadata={'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '1_1', 'type': 'table', 'prio': 'alcance', 'page': 1}, page_content='SECCIÓN | DESCRIPCIÓN\n2 | ALCANCE DEL SUMINISTRO\n10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)'),
#  Document(metadata={'page': 1, 'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '1_1', 'prio': 'alcance'}, page_content='SECCIÓN | DESCRIPCIÓN\n2 | ALCANCE DEL SUMINISTRO\n10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)'),
#  Document(metadata={'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'table', 'prio': 'alcance', 'page': 1, 'chunk_id': '1_1'}, page_content='SECCIÓN | DESCRIPCIÓN\n2 | ALCANCE DEL SUMINISTRO\n10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)'),
#  Document(metadata={'prio': 'alcance', 'kv': '{"SECCIÓN": "DESCRIPCIÓN", "2": "ALCANCE DEL SUMINISTRO", "10.3": "DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)"}', 'type': 'table', 'page': 1, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '1_1'}, page_content='SECCIÓN | DESCRIPCIÓN\n2 | ALCANCE DEL SUMINISTRO\n10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)'),
#  Document(metadata={'page': 1, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'table', 'prio': 'alcance', 'chunk_id': '1_1'}, page_content='SECCIÓN | DESCRIPCIÓN\n2 | ALCANCE DEL SUMINISTRO\n10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)'),
#  Document(metadata={'page': 1, 'prio': 'alcance', 'chunk_id': '1_1', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'table'}, page_content='SECCIÓN | DESCRIPCIÓN\n2 | ALCANCE DEL SUMINISTRO\n10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)')]

# %%
# ============================================
# Paso 10 - Validar TODOS los metadatos (corregido)
# ============================================
from collections import Counter

def validar_metadatos_globales():
    """Valida consistencia de metadatos en la colección completa."""
    collection = vectorstore._collection
    data = collection.get(include=["metadatas", "documents"])

    total_docs = len(data["documents"])
    print(f"🔎 Total de registros en la colección: {total_docs}")

    errores = 0
    prio_counts = Counter()
    type_counts = Counter()
    kv_count = 0
    seen_ids = set()
    duplicados = 0

    for i, meta in enumerate(data["metadatas"]):
        doc_id = data["ids"][i]  # aquí sí podemos usarlo, ya viene siempre

        # Detectar duplicados de ID
        if doc_id in seen_ids:
            duplicados += 1
        else:
            seen_ids.add(doc_id)

        # Validar claves mínimas
        if not all(key in meta for key in ["source", "page", "type"]):
            print(f"⚠️ Registro {i} con metadatos incompletos:", meta)
            errores += 1
            continue

        # Validar valores
        if not isinstance(meta.get("page"), int) or meta["page"] <= 0:
            print(f"⚠️ Registro {i} con página inválida:", meta)
            errores += 1

        if not meta.get("type"):
            print(f"⚠️ Registro {i} con tipo vacío:", meta)
            errores += 1

        # Contadores útiles
        prio_counts[meta.get("prio", "none")] += 1
        type_counts[meta.get("type", "unknown")] += 1
        if "kv" in meta:
            kv_count += 1

    # Resumen
    if errores == 0:
        print("✅ Todos los documentos tienen metadatos completos y válidos.")
    else:
        print(f"⚠️ Se encontraron {errores} problemas de metadatos.")

    if duplicados > 0:
        print(f"⚠️ Se detectaron {duplicados} duplicados de IDs.")

    print("\n📊 Distribución por prioridad:", dict(prio_counts))
    print("📊 Distribución por tipo:", dict(type_counts))
    print(f"📊 Total de documentos con KV (tablas clave-valor): {kv_count}")

# Ejemplo:
validar_metadatos_globales()
# Out:
# 🔎 Total de registros en la colección: 7369
# ✅ Todos los documentos tienen metadatos completos y válidos.
#
# 📊 Distribución por prioridad: {'alcance': 1298, 'general': 1604, 'hoja_datos': 2370, 'norma': 988, 'requisito': 1109}
# 📊 Distribución por tipo: {'text': 4632, 'table': 2737}
# 📊 Total de documentos con KV (tablas clave-valor): 1836

# %%
# ============================================
# Paso 11 - Buscar solo tablas o solo texto
# ============================================
def buscar_por_tipo(tipo: str = "table", pregunta: str = "bomba dosificadora", k: int = 5):
    """
    Recupera fragmentos filtrando por tipo ('table' o 'text').
    """
    retriever = vectorstore.as_retriever(
        search_kwargs={"k": k, "filter": {"type": tipo}}
    )
    results = retriever.get_relevant_documents(pregunta)

    print(f"\n🔎 Resultados filtrados por tipo='{tipo}' | pregunta='{pregunta}' → {len(results)} encontrados")
    for i, r in enumerate(results, 1):
        print(f"\n--- CHUNK {i} ---")
        print(r.page_content[:400].replace("\n", " "))
        print("Metadatos:", r.metadata)

        if "kv" in r.metadata:  # Mostrar KV si existe
            try:
                import json
                print("KV:", json.loads(r.metadata["kv"]))
            except Exception:
                print("KV (raw):", r.metadata["kv"])

    return results


# Ejemplos de prueba:
buscar_por_tipo("table", "tags y cantidades")
buscar_por_tipo("text", "alcance del suministro")
# Out:
# 🔎 Resultados filtrados por tipo='table' | pregunta='tags y cantidades' → 5 encontrados
#
# --- CHUNK 1 ---
# | | requerían clasificación.
# Metadatos: {'chunk_id': '51_1', 'page': 51, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'table', 'prio': 'general'}
#
# --- CHUNK 2 ---
# requerían clasificación.
# Metadatos: {'prio': 'general', 'page': 51, 'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '51_1'}
#
# --- CHUNK 3 ---
# requerían clasificación.
# Metadatos: {'type': 'table', 'page': 51, 'chunk_id': '51_1', 'prio': 'general', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}
#
# --- CHUNK 4 ---
# requerían clasificación.
# Metadatos: {'type': 'table', 'chunk_id': '51_1', 'prio': 'general', 'page': 51, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}
#
# --- CHUNK 5 ---
# requerían clasificación.
# Metadatos: {'prio': 'general', 'page': 51, 'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '51_1'}
#
# 🔎 Resultados filtrados por tipo='text' | pregunta='alcance del suministro' → 5 encontrados
#
# --- CHUNK 1 ---
# 2.0 ALCANCE Este documento describe el alcance del suministro y servicios del PROVEEDOR, sus responsabilidades, plan de ejecución y demás aspectos generales para el diseño; fabricación; suministro; asistencia para el montaje y pruebas del PAQUETE de inyección de químicos de Polímero Aniónico AX-75317 y los Quill´s de Inyección Retráctil roscado, completamente operacionales y funcionales. Los detal
# Metadatos: {'page': 58, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'text', 'chunk_id': '58_2', 'prio': 'hoja_datos'}
#
# --- CHUNK 2 ---
# 2.0 ALCANCE Este documento describe el alcance del suministro y servicios del PROVEEDOR, sus responsabilidades, plan de ejecución y demás aspectos generales para el diseño; fabricación; suministro; asistencia para el montaje y pruebas del PAQUETE de inyección de químicos de Polímero Aniónico AX-75317 y los Quill´s de Inyección Retráctil roscado, completamente operacionales y funcionales. Los detal
# Metadatos: {'type': 'text', 'prio': 'hoja_datos', 'page': 58, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '58_2'}
#
# --- CHUNK 3 ---
# 2.0 ALCANCE Este documento describe el alcance del suministro y servicios del PROVEEDOR, sus responsabilidades, plan de ejecución y demás aspectos generales para el diseño; fabricación; suministro; asistencia para el montaje y pruebas del PAQUETE de inyección de químicos de Polímero Aniónico AX-75317 y los Quill´s de Inyección Retráctil roscado, completamente operacionales y funcionales. Los detal
# Metadatos: {'prio': 'hoja_datos', 'type': 'text', 'chunk_id': '58_2', 'page': 58, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}
#
# --- CHUNK 4 ---
# 2.0 ALCANCE Este documento describe el alcance del suministro y servicios del PROVEEDOR, sus responsabilidades, plan de ejecución y demás aspectos generales para el diseño; fabricación; suministro; asistencia para el montaje y pruebas del PAQUETE de inyección de químicos de Polímero Aniónico AX-75317 y los Quill´s de Inyección Retráctil roscado, completamente operacionales y funcionales. Los detal
# Metadatos: {'page': 58, 'prio': 'hoja_datos', 'type': 'text', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '58_2'}
#
# --- CHUNK 5 ---
# 2.0 ALCANCE Este documento describe el alcance del suministro y servicios del PROVEEDOR, sus responsabilidades, plan de ejecución y demás aspectos generales para el diseño; fabricación; suministro; asistencia para el montaje y pruebas del PAQUETE de inyección de químicos de Polímero Aniónico AX-75317 y los Quill´s de Inyección Retráctil roscado, completamente operacionales y funcionales. Los detal
# Metadatos: {'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '58_2', 'page': 58, 'type': 'text', 'prio': 'hoja_datos'}
# [Document(metadata={'page': 58, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'text', 'chunk_id': '58_2', 'prio': 'hoja_datos'}, page_content='2.0 ALCANCE\nEste documento describe el alcance del suministro y servicios del PROVEEDOR, sus\nresponsabilidades, plan de ejecución y demás aspectos generales para el diseño; fabricación;\nsuministro; asistencia para el montaje y pruebas del PAQUETE de inyección de químicos de Polímero\nAniónico AX-75317 y los Quill´s de Inyección Retráctil roscado, completamente operacionales y\nfuncionales.\nLos detalles relevantes a los requerimientos de proceso, características constructivas, garantías de\ndesempeño y otros requerimientos están incluidos en este documento.\nEsta especificación debe ser leída en conjunto con:\n• CAS-09991-MER-HD-000003: HOJA DE DATOS PAQUETE DE QUÍMICA STAP EC3.\n• CAS-09991-PRO-PID-000012: DIAGRAMA DE TUBERÍA E INSTRUMENTACIÓN SISTEMA'),
#  Document(metadata={'type': 'text', 'prio': 'hoja_datos', 'page': 58, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '58_2'}, page_content='2.0 ALCANCE\nEste documento describe el alcance del suministro y servicios del PROVEEDOR, sus\nresponsabilidades, plan de ejecución y demás aspectos generales para el diseño; fabricación;\nsuministro; asistencia para el montaje y pruebas del PAQUETE de inyección de químicos de Polímero\nAniónico AX-75317 y los Quill´s de Inyección Retráctil roscado, completamente operacionales y\nfuncionales.\nLos detalles relevantes a los requerimientos de proceso, características constructivas, garantías de\ndesempeño y otros requerimientos están incluidos en este documento.\nEsta especificación debe ser leída en conjunto con:\n• CAS-09991-MER-HD-000003: HOJA DE DATOS PAQUETE DE QUÍMICA STAP EC3.\n• CAS-09991-PRO-PID-000012: DIAGRAMA DE TUBERÍA E INSTRUMENTACIÓN SISTEMA'),
#  Document(metadata={'prio': 'hoja_datos', 'type': 'text', 'chunk_id': '58_2', 'page': 58, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}, page_content='2.0 ALCANCE\nEste documento describe el alcance del suministro y servicios del PROVEEDOR, sus\nresponsabilidades, plan de ejecución y demás aspectos generales para el diseño; fabricación;\nsuministro; asistencia para el montaje y pruebas del PAQUETE de inyección de químicos de Polímero\nAniónico AX-75317 y los Quill´s de Inyección Retráctil roscado, completamente operacionales y\nfuncionales.\nLos detalles relevantes a los requerimientos de proceso, características constructivas, garantías de\ndesempeño y otros requerimientos están incluidos en este documento.\nEsta especificación debe ser leída en conjunto con:\n• CAS-09991-MER-HD-000003: HOJA DE DATOS PAQUETE DE QUÍMICA STAP EC3.\n• CAS-09991-PRO-PID-000012: DIAGRAMA DE TUBERÍA E INSTRUMENTACIÓN SISTEMA'),
#  Document(metadata={'page': 58, 'prio': 'hoja_datos', 'type': 'text', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '58_2'}, page_content='2.0 ALCANCE\nEste documento describe el alcance del suministro y servicios del PROVEEDOR, sus\nresponsabilidades, plan de ejecución y demás aspectos generales para el diseño; fabricación;\nsuministro; asistencia para el montaje y pruebas del PAQUETE de inyección de químicos de Polímero\nAniónico AX-75317 y los Quill´s de Inyección Retráctil roscado, completamente operacionales y\nfuncionales.\nLos detalles relevantes a los requerimientos de proceso, características constructivas, garantías de\ndesempeño y otros requerimientos están incluidos en este documento.\nEsta especificación debe ser leída en conjunto con:\n• CAS-09991-MER-HD-000003: HOJA DE DATOS PAQUETE DE QUÍMICA STAP EC3.\n• CAS-09991-PRO-PID-000012: DIAGRAMA DE TUBERÍA E INSTRUMENTACIÓN SISTEMA'),
#  Document(metadata={'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '58_2', 'page': 58, 'type': 'text', 'prio': 'hoja_datos'}, page_content='2.0 ALCANCE\nEste documento describe el alcance del suministro y servicios del PROVEEDOR, sus\nresponsabilidades, plan de ejecución y demás aspectos generales para el diseño; fabricación;\nsuministro; asistencia para el montaje y pruebas del PAQUETE de inyección de químicos de Polímero\nAniónico AX-75317 y los Quill´s de Inyección Retráctil roscado, completamente operacionales y\nfuncionales.\nLos detalles relevantes a los requerimientos de proceso, características constructivas, garantías de\ndesempeño y otros requerimientos están incluidos en este documento.\nEsta especificación debe ser leída en conjunto con:\n• CAS-09991-MER-HD-000003: HOJA DE DATOS PAQUETE DE QUÍMICA STAP EC3.\n• CAS-09991-PRO-PID-000012: DIAGRAMA DE TUBERÍA E INSTRUMENTACIÓN SISTEMA')]

# %%
# ============================================
# Paso 11.1 - Comparar resultados table vs text
# ============================================
from collections import Counter
import json

def comparar_table_vs_text(pregunta="alcance del suministro", k=6):
    resultados = {}
    for tipo in ["table", "text"]:
        retriever = vectorstore.as_retriever(
            search_kwargs={"k": k, "filter": {"type": tipo}}
        )
        docs = retriever.get_relevant_documents(pregunta)
        resultados[tipo] = docs

        print(f"\n🔎 Resultados filtrados por tipo='{tipo}' → {len(docs)} encontrados")
        prio_counter = Counter([d.metadata.get("prio", "none") for d in docs])
        kv_count = sum(1 for d in docs if "kv" in d.metadata)

        print(f"📊 Distribución de prioridades: {dict(prio_counter)}")
        print(f"📊 Con KV extraídos: {kv_count}")

        for r in docs:
            print("\n--- CHUNK ---")
            print(r.page_content[:300].replace("\n", " "))
            print("Metadatos:", r.metadata)
            if "kv" in r.metadata:
                try:
                    print("KV:", json.loads(r.metadata["kv"]))
                except:
                    print("KV (raw):", r.metadata["kv"])

    # Comparación final
    print("\n================= RESUMEN COMPARATIVO =================")
    for tipo in ["table", "text"]:
        print(f"Tipo: {tipo} | Total: {len(resultados[tipo])}")
        kv_total = sum(1 for d in resultados[tipo] if "kv" in d.metadata)
        print(f" → Con KV: {kv_total}")
        prio_counter = Counter([d.metadata.get("prio", "none") for d in resultados[tipo]])
        print(f" → Prioridades: {dict(prio_counter)}")

# Ejemplo de prueba
comparar_table_vs_text("tags y cantidades", k=5)
comparar_table_vs_text("alcance del suministro", k=5)
# Out:
# 🔎 Resultados filtrados por tipo='table' → 5 encontrados
# 📊 Distribución de prioridades: {'general': 5}
# 📊 Con KV extraídos: 0
#
# --- CHUNK ---
# | | requerían clasificación.
# Metadatos: {'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'general', 'page': 51, 'chunk_id': '51_1'}
#
# --- CHUNK ---
# requerían clasificación.
# Metadatos: {'prio': 'general', 'chunk_id': '51_1', 'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 51}
#
# --- CHUNK ---
# requerían clasificación.
# Metadatos: {'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '51_1', 'page': 51, 'prio': 'general', 'type': 'table'}
#
# --- CHUNK ---
# requerían clasificación.
# Metadatos: {'chunk_id': '51_1', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'general', 'page': 51, 'type': 'table'}
#
# --- CHUNK ---
# requerían clasificación.
# Metadatos: {'prio': 'general', 'page': 51, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'table', 'chunk_id': '51_1'}
#
# 🔎 Resultados filtrados por tipo='text' → 5 encontrados
# 📊 Distribución de prioridades: {'hoja_datos': 2, 'norma': 3}
# 📊 Con KV extraídos: 4
#
# --- CHUNK ---
# MAYORES PAQUETES DE INYECCIÓN DE QUÍMICOS
# Metadatos: {'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'text', 'kv': '{"api_675": "true"}', 'chunk_id': '9_1', 'prio': 'hoja_datos', 'page': 9}
# KV: {'api_675': 'true'}
#
# --- CHUNK ---
# MAYORES PAQUETES DE INYECCIÓN DE QUÍMICOS
# Metadatos: {'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '29_1', 'page': 29, 'prio': 'norma', 'type': 'text'}
#
# --- CHUNK ---
# MAYORES PAQUETES DE INYECCIÓN DE QUÍMICOS
# Metadatos: {'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 32, 'type': 'text', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'prio': 'hoja_datos', 'chunk_id': '32_1'}
# KV: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS', 'api_675': 'true'}
#
# --- CHUNK ---
# MAYORES PAQUETES DE INYECCIÓN DE QUÍMICOS
# Metadatos: {'prio': 'norma', 'page': 33, 'type': 'text', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '33_1', 'kv': '{"presion_psig": "100", "material_tanque": "304SS"}'}
# KV: {'presion_psig': '100', 'material_tanque': '304SS'}
#
# --- CHUNK ---
# MAYORES PAQUETES DE INYECCIÓN DE QUÍMICOS
# Metadatos: {'chunk_id': '34_1', 'type': 'text', 'page': 34, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'kv': '{"presion_psig": "100"}', 'prio': 'norma'}
# KV: {'presion_psig': '100'}
#
# ================= RESUMEN COMPARATIVO =================
# Tipo: table | Total: 5
#  → Con KV: 0
#  → Prioridades: {'general': 5}
# Tipo: text | Total: 5
#  → Con KV: 4
#  → Prioridades: {'hoja_datos': 2, 'norma': 3}
#
# 🔎 Resultados filtrados por tipo='table' → 5 encontrados
# 📊 Distribución de prioridades: {'alcance': 5}
# 📊 Con KV extraídos: 0
#
# --- CHUNK ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'type': 'table', 'chunk_id': '1_1', 'page': 1, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'alcance'}
#
# --- CHUNK ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'page': 1, 'prio': 'alcance', 'chunk_id': '1_1', 'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}
#
# --- CHUNK ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'prio': 'alcance', 'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 1, 'chunk_id': '1_1'}
#
# --- CHUNK ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '1_1', 'type': 'table', 'page': 1, 'prio': 'alcance'}
#
# --- CHUNK ---
# SECCIÓN | DESCRIPCIÓN 2 | ALCANCE DEL SUMINISTRO 10.3 | DOCUMENTOS DE REFERENCIA (ACTUALIZA ÚLTIMA REVISIÓN)
# Metadatos: {'chunk_id': '1_1', 'prio': 'alcance', 'type': 'table', 'page': 1, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}
#
# 🔎 Resultados filtrados por tipo='text' → 5 encontrados
# 📊 Distribución de prioridades: {'hoja_datos': 5}
# 📊 Con KV extraídos: 0
#
# --- CHUNK ---
# 2.0 ALCANCE Este documento describe el alcance del suministro y servicios del PROVEEDOR, sus responsabilidades, plan de ejecución y demás aspectos generales para el diseño; fabricación; suministro; asistencia para el montaje y pruebas del PAQUETE de inyección de químicos de Polímero Aniónico AX-7531
# Metadatos: {'prio': 'hoja_datos', 'page': 58, 'type': 'text', 'chunk_id': '58_2', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}
#
# --- CHUNK ---
# 2.0 ALCANCE Este documento describe el alcance del suministro y servicios del PROVEEDOR, sus responsabilidades, plan de ejecución y demás aspectos generales para el diseño; fabricación; suministro; asistencia para el montaje y pruebas del PAQUETE de inyección de químicos de Polímero Aniónico AX-7531
# Metadatos: {'page': 58, 'prio': 'hoja_datos', 'type': 'text', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '58_2'}
#
# --- CHUNK ---
# 2.0 ALCANCE Este documento describe el alcance del suministro y servicios del PROVEEDOR, sus responsabilidades, plan de ejecución y demás aspectos generales para el diseño; fabricación; suministro; asistencia para el montaje y pruebas del PAQUETE de inyección de químicos de Polímero Aniónico AX-7531
# Metadatos: {'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '58_2', 'prio': 'hoja_datos', 'page': 58, 'type': 'text'}
#
# --- CHUNK ---
# 2.0 ALCANCE Este documento describe el alcance del suministro y servicios del PROVEEDOR, sus responsabilidades, plan de ejecución y demás aspectos generales para el diseño; fabricación; suministro; asistencia para el montaje y pruebas del PAQUETE de inyección de químicos de Polímero Aniónico AX-7531
# Metadatos: {'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'text', 'chunk_id': '58_2', 'page': 58}
#
# --- CHUNK ---
# 2.0 ALCANCE Este documento describe el alcance del suministro y servicios del PROVEEDOR, sus responsabilidades, plan de ejecución y demás aspectos generales para el diseño; fabricación; suministro; asistencia para el montaje y pruebas del PAQUETE de inyección de químicos de Polímero Aniónico AX-7531
# Metadatos: {'page': 58, 'chunk_id': '58_2', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'hoja_datos', 'type': 'text'}
#
# ================= RESUMEN COMPARATIVO =================
# Tipo: table | Total: 5
#  → Con KV: 0
#  → Prioridades: {'alcance': 5}
# Tipo: text | Total: 5
#  → Con KV: 0
#  → Prioridades: {'hoja_datos': 5}

# %%
# ============================================
# Paso 12 - Buscar en una página específica
# ============================================
def buscar_por_pagina(pagina: int, pregunta: str):
    retriever = vectorstore.as_retriever(
        search_kwargs={"k": 5, "filter": {"page": pagina}}
    )
    results = retriever.get_relevant_documents(pregunta)

    print(f"🔎 Resultados en página {pagina}: {len(results)}")
    for r in results:
        print("\n--- CHUNK ---")
        print(r.page_content[:400].replace("\n", " "))
        print("Metadatos:", r.metadata)

# Ejemplo:
buscar_por_pagina(32, "alcance del suministro")
buscar_por_pagina(42, "caudal de la bomba")
# Out:
# 🔎 Resultados en página 32: 5
#
# --- CHUNK ---
# componentes, o dieciocho (18) meses a partir de la entrega a satisfacción de estos por parte de ECOPETROL S.A. Durante este período la garantía debe cubrir la reparación o reemplazo de los componentes defectuosos por parte del VENDEDOR incluyendo todas las labores, equipos, transporte y demás costos generados y requeridos para llevar a cabo dicha reparación y/o reemplazo. 10. ANEXOS 10.1. LISTA DE
# Metadatos: {'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 32, 'type': 'text', 'prio': 'hoja_datos', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'chunk_id': '32_3'}
#
# --- CHUNK ---
# componentes, o dieciocho (18) meses a partir de la entrega a satisfacción de estos por parte de ECOPETROL S.A. Durante este período la garantía debe cubrir la reparación o reemplazo de los componentes defectuosos por parte del VENDEDOR incluyendo todas las labores, equipos, transporte y demás costos generados y requeridos para llevar a cabo dicha reparación y/o reemplazo. 10. ANEXOS 10.1. LISTA DE
# Metadatos: {'chunk_id': '32_3', 'prio': 'hoja_datos', 'page': 32, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'type': 'text'}
#
# --- CHUNK ---
# componentes, o dieciocho (18) meses a partir de la entrega a satisfacción de estos por parte de ECOPETROL S.A. Durante este período la garantía debe cubrir la reparación o reemplazo de los componentes defectuosos por parte del VENDEDOR incluyendo todas las labores, equipos, transporte y demás costos generados y requeridos para llevar a cabo dicha reparación y/o reemplazo. 10. ANEXOS 10.1. LISTA DE
# Metadatos: {'type': 'text', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 32, 'prio': 'hoja_datos', 'chunk_id': '32_3'}
#
# --- CHUNK ---
# componentes, o dieciocho (18) meses a partir de la entrega a satisfacción de estos por parte de ECOPETROL S.A. Durante este período la garantía debe cubrir la reparación o reemplazo de los componentes defectuosos por parte del VENDEDOR incluyendo todas las labores, equipos, transporte y demás costos generados y requeridos para llevar a cabo dicha reparación y/o reemplazo. 10. ANEXOS 10.1. LISTA DE
# Metadatos: {'page': 32, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'text', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'chunk_id': '32_3', 'prio': 'hoja_datos'}
#
# --- CHUNK ---
# componentes, o dieciocho (18) meses a partir de la entrega a satisfacción de estos por parte de ECOPETROL S.A. Durante este período la garantía debe cubrir la reparación o reemplazo de los componentes defectuosos por parte del VENDEDOR incluyendo todas las labores, equipos, transporte y demás costos generados y requeridos para llevar a cabo dicha reparación y/o reemplazo. 10. ANEXOS 10.1. LISTA DE
# Metadatos: {'type': 'text', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'chunk_id': '32_3', 'prio': 'hoja_datos', 'page': 32}
# 🔎 Resultados en página 42: 5
#
# --- CHUNK ---
# 17 18 19 | NÓICATSE | DESCRIPCIÓN - BOMBA POZO / FORMACIÓN | TIPO DE QUÍMICO | CANTIDAD CAMARAS | CAPACIDAD (gal) | MATERIAL | POTENCIA AGITADORES (NOTA 15) | MODELO | CANTIDAD | CAUDAL DE INYECCIÓN (GPH) | MODELO | RANGO (Cps) | POTENCIA MOTOR ELECTRICO (hp) (NOTA 15) | CANTIDAD 20 21 22 23 24 25 26 27 28 | STAP EC3 (NOTA 18) AFC4 | Se requiere una unidad paquete de Preparación y Dosificación sob
# Metadatos: {'page': 42, 'type': 'table', 'chunk_id': '42_3', 'kv': '{"caudal_gph": "18", "presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "rango_cps_min": "500", "rango_cps_max": "1000", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}', 'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}
#
# --- CHUNK ---
# 17 18 19 | NÓICATSE | DESCRIPCIÓN - BOMBA POZO / FORMACIÓN | TIPO DE QUÍMICO | CANTIDAD CAMARAS | CAPACIDAD (gal) | MATERIAL | POTENCIA AGITADORES (NOTA 15) | MODELO | CANTIDAD | CAUDAL DE INYECCIÓN (GPH) | MODELO | RANGO (Cps) | POTENCIA MOTOR ELECTRICO (hp) (NOTA 15) | CANTIDAD 20 21 22 23 24 25 26 27 28 | STAP EC3 (NOTA 18) AFC4 | Se requiere una unidad paquete de Preparación y Dosificación sob
# Metadatos: {'kv': '{"caudal_gph": "18", "presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "rango_cps_min": "500", "rango_cps_max": "1000", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}', 'page': 42, 'chunk_id': '42_3', 'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'hoja_datos'}
#
# --- CHUNK ---
# 17 18 19 | NÓICATSE | DESCRIPCIÓN - BOMBA POZO / FORMACIÓN | TIPO DE QUÍMICO | CANTIDAD CAMARAS | CAPACIDAD (gal) | MATERIAL | POTENCIA AGITADORES (NOTA 15) | MODELO | CANTIDAD | CAUDAL DE INYECCIÓN (GPH) | MODELO | RANGO (Cps) | POTENCIA MOTOR ELECTRICO (hp) (NOTA 15) | CANTIDAD 20 21 22 23 24 25 26 27 28 | STAP EC3 (NOTA 18) AFC4 | Se requiere una unidad paquete de Preparación y Dosificación sob
# Metadatos: {'type': 'table', 'chunk_id': '42_3', 'kv': '{"caudal_gph": "18", "presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "rango_cps_min": "500", "rango_cps_max": "1000", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 42, 'prio': 'hoja_datos'}
#
# --- CHUNK ---
# 17 18 19 | NÓICATSE | DESCRIPCIÓN - BOMBA POZO / FORMACIÓN | TIPO DE QUÍMICO | CANTIDAD CAMARAS | CAPACIDAD (gal) | MATERIAL | POTENCIA AGITADORES (NOTA 15) | MODELO | CANTIDAD | CAUDAL DE INYECCIÓN (GPH) | MODELO | RANGO (Cps) | POTENCIA MOTOR ELECTRICO (hp) (NOTA 15) | CANTIDAD 20 21 22 23 24 25 26 27 28 | STAP EC3 (NOTA 18) AFC4 | Se requiere una unidad paquete de Preparación y Dosificación sob
# Metadatos: {'kv': '{"caudal_gph": "18", "presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "rango_cps_min": "500", "rango_cps_max": "1000", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}', 'type': 'table', 'chunk_id': '42_3', 'prio': 'hoja_datos', 'page': 42, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}
#
# --- CHUNK ---
# 17 18 19 | NÓICATSE | DESCRIPCIÓN - BOMBA POZO / FORMACIÓN | TIPO DE QUÍMICO | CANTIDAD CAMARAS | CAPACIDAD (gal) | MATERIAL | POTENCIA AGITADORES (NOTA 15) | MODELO | CANTIDAD | CAUDAL DE INYECCIÓN (GPH) | MODELO | RANGO (Cps) | POTENCIA MOTOR ELECTRICO (hp) (NOTA 15) | CANTIDAD 20 21 22 23 24 25 26 27 28 | STAP EC3 (NOTA 18) AFC4 | Se requiere una unidad paquete de Preparación y Dosificación sob
# Metadatos: {'prio': 'hoja_datos', 'type': 'table', 'chunk_id': '42_3', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'kv': '{"caudal_gph": "18", "presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "rango_cps_min": "500", "rango_cps_max": "1000", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}', 'page': 42}

# %%
# ============================================
# Paso 13.1 – Inventario de sistemas (Skids, TAGs y cantidades)
# ============================================

import json

def prueba_inventario_sistemas():
    pregunta = "¿Cuáles son los skids o sistemas de dosificación requeridos? Dame los TAG y las cantidades."
    retriever = vectorstore.as_retriever(
        search_kwargs={"k": 10, "filter": {"type": "table"}}
    )
    results = retriever.get_relevant_documents(pregunta)

    print(f"🔎 Resultados prueba INVENTARIO (skids + tags + cantidades): {len(results)}")

    kv_count = 0
    for r in results:
        print("\n--- CHUNK INVENTARIO ---")
        print(r.page_content[:400].replace("\n", " "))
        print("Metadatos:", r.metadata)

        if "kv" in r.metadata:
            try:
                kv_dict = json.loads(r.metadata["kv"])
                print("KV dict:", kv_dict)
                kv_count += 1
            except Exception:
                print("KV (raw):", r.metadata["kv"])

    print(f"\n📊 Total de chunks con KV útiles: {kv_count}")

# Ejemplo de ejecución
prueba_inventario_sistemas()
# Out:
# 🔎 Resultados prueba INVENTARIO (skids + tags + cantidades): 10
#
# --- CHUNK INVENTARIO ---
# SKID. -INSTALACIÓN DE CABLEADOS INTERNOS DE ELÉCTRICIDAD E INSTRUMENTACIÓN, ASÍ COMO INTERCONEXIONES DE LOS EQUIPOS ROTATIVOS Y ESTÁTICOS QUE INTEGRAN EL SKID. -SISTEMA DE CONTROL LOCAL DEL SKID, QUE CUENTEN CON PUERTOS DE FIBRA ÓPTICA Y PROTOCOLO MODBUS TCP/IP PARA COMUNICACIÓN CON EL SISTEMA DE CONTROL DEL STAP EC3; CONTROLADOR PCS-009. 2. DE ACUERDO A INFORMACIÓN DEL PROVEEDOR DEL SKID DE QUÍMI
# Metadatos: {'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '54_3', 'page': 54, 'type': 'table', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS"}', 'prio': 'alcance'}
# KV dict: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS'}
#
# --- CHUNK INVENTARIO ---
# SKID. -INSTALACIÓN DE CABLEADOS INTERNOS DE ELÉCTRICIDAD E INSTRUMENTACIÓN, ASÍ COMO INTERCONEXIONES DE LOS EQUIPOS ROTATIVOS Y ESTÁTICOS QUE INTEGRAN EL SKID. -SISTEMA DE CONTROL LOCAL DEL SKID, QUE CUENTEN CON PUERTOS DE FIBRA ÓPTICA Y PROTOCOLO MODBUS TCP/IP PARA COMUNICACIÓN CON EL SISTEMA DE CONTROL DEL STAP EC3; CONTROLADOR PCS-009. 2. DE ACUERDO A INFORMACIÓN DEL PROVEEDOR DEL SKID DE QUÍMI
# Metadatos: {'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS"}', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 54, 'prio': 'alcance', 'chunk_id': '54_3', 'type': 'table'}
# KV dict: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS'}
#
# --- CHUNK INVENTARIO ---
# SKID. -INSTALACIÓN DE CABLEADOS INTERNOS DE ELÉCTRICIDAD E INSTRUMENTACIÓN, ASÍ COMO INTERCONEXIONES DE LOS EQUIPOS ROTATIVOS Y ESTÁTICOS QUE INTEGRAN EL SKID. -SISTEMA DE CONTROL LOCAL DEL SKID, QUE CUENTEN CON PUERTOS DE FIBRA ÓPTICA Y PROTOCOLO MODBUS TCP/IP PARA COMUNICACIÓN CON EL SISTEMA DE CONTROL DEL STAP EC3; CONTROLADOR PCS-009. 2. DE ACUERDO A INFORMACIÓN DEL PROVEEDOR DEL SKID DE QUÍMI
# Metadatos: {'chunk_id': '54_3', 'prio': 'alcance', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'table', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS"}', 'page': 54}
# KV dict: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS'}
#
# --- CHUNK INVENTARIO ---
# SKID. -INSTALACIÓN DE CABLEADOS INTERNOS DE ELÉCTRICIDAD E INSTRUMENTACIÓN, ASÍ COMO INTERCONEXIONES DE LOS EQUIPOS ROTATIVOS Y ESTÁTICOS QUE INTEGRAN EL SKID. -SISTEMA DE CONTROL LOCAL DEL SKID, QUE CUENTEN CON PUERTOS DE FIBRA ÓPTICA Y PROTOCOLO MODBUS TCP/IP PARA COMUNICACIÓN CON EL SISTEMA DE CONTROL DEL STAP EC3; CONTROLADOR PCS-009. 2. DE ACUERDO A INFORMACIÓN DEL PROVEEDOR DEL SKID DE QUÍMI
# Metadatos: {'chunk_id': '54_3', 'prio': 'alcance', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS"}', 'page': 54, 'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}
# KV dict: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS'}
#
# --- CHUNK INVENTARIO ---
# SKID. -INSTALACIÓN DE CABLEADOS INTERNOS DE ELÉCTRICIDAD E INSTRUMENTACIÓN, ASÍ COMO INTERCONEXIONES DE LOS EQUIPOS ROTATIVOS Y ESTÁTICOS QUE INTEGRAN EL SKID. -SISTEMA DE CONTROL LOCAL DEL SKID, QUE CUENTEN CON PUERTOS DE FIBRA ÓPTICA Y PROTOCOLO MODBUS TCP/IP PARA COMUNICACIÓN CON EL SISTEMA DE CONTROL DEL STAP EC3; CONTROLADOR PCS-009. 2. DE ACUERDO A INFORMACIÓN DEL PROVEEDOR DEL SKID DE QUÍMI
# Metadatos: {'chunk_id': '54_3', 'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 54, 'prio': 'alcance', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS"}'}
# KV dict: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS'}
#
# --- CHUNK INVENTARIO ---
# SKID. -INSTALACIÓN DE CABLEADOS INTERNOS DE ELÉCTRICIDAD E INSTRUMENTACIÓN, ASÍ COMO INTERCONEXIONES DE LOS EQUIPOS ROTATIVOS Y ESTÁTICOS QUE INTEGRAN EL SKID. -SISTEMA DE CONTROL LOCAL DEL SKID, QUE CUENTEN CON PUERTOS DE FIBRA ÓPTICA Y PROTOCOLO MODBUS TCP/IP PARA COMUNICACIÓN CON EL SISTEMA DE CONTROL DEL STAP EC3; CONTROLADOR PCS-009. 2. DE ACUERDO A INFORMACIÓN DEL PROVEEDOR DEL SKID DE QUÍMI
# Metadatos: {'prio': 'alcance', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS"}', 'chunk_id': '54_3', 'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 54}
# KV dict: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS'}
#
# --- CHUNK INVENTARIO ---
# SKID. -INSTALACIÓN DE CABLEADOS INTERNOS DE ELÉCTRICIDAD E INSTRUMENTACIÓN, ASÍ COMO INTERCONEXIONES DE LOS EQUIPOS ROTATIVOS Y ESTÁTICOS QUE INTEGRAN EL SKID. -SISTEMA DE CONTROL LOCAL DEL SKID, QUE CUENTEN CON PUERTOS DE FIBRA ÓPTICA Y PROTOCOLO MODBUS TCP/IP PARA COMUNICACIÓN CON EL SISTEMA DE CONTROL DEL STAP EC3; CONTROLADOR PCS-009. 2. DE ACUERDO A INFORMACIÓN DEL PROVEEDOR DEL SKID DE QUÍMI
# Metadatos: {'page': 54, 'prio': 'alcance', 'type': 'table', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS"}', 'chunk_id': '54_3', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}
# KV dict: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS'}
#
# --- CHUNK INVENTARIO ---
# SKID. -INSTALACIÓN DE CABLEADOS INTERNOS DE ELÉCTRICIDAD E INSTRUMENTACIÓN, ASÍ COMO INTERCONEXIONES DE LOS EQUIPOS ROTATIVOS Y ESTÁTICOS QUE INTEGRAN EL SKID. -SISTEMA DE CONTROL LOCAL DEL SKID, QUE CUENTEN CON PUERTOS DE FIBRA ÓPTICA Y PROTOCOLO MODBUS TCP/IP PARA COMUNICACIÓN CON EL SISTEMA DE CONTROL DEL STAP EC3; CONTROLADOR PCS-009. 2. DE ACUERDO A INFORMACIÓN DEL PROVEEDOR DEL SKID DE QUÍMI
# Metadatos: {'chunk_id': '54_3', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'alcance', 'page': 54, 'type': 'table', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS"}'}
# KV dict: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS'}
#
# --- CHUNK INVENTARIO ---
# SKID. -INSTALACIÓN DE CABLEADOS INTERNOS DE ELÉCTRICIDAD E INSTRUMENTACIÓN, ASÍ COMO INTERCONEXIONES DE LOS EQUIPOS ROTATIVOS Y ESTÁTICOS QUE INTEGRAN EL SKID. -SISTEMA DE CONTROL LOCAL DEL SKID, QUE CUENTEN CON PUERTOS DE FIBRA ÓPTICA Y PROTOCOLO MODBUS TCP/IP PARA COMUNICACIÓN CON EL SISTEMA DE CONTROL DEL STAP EC3; CONTROLADOR PCS-009. 2. DE ACUERDO A INFORMACIÓN DEL PROVEEDOR DEL SKID DE QUÍMI
# Metadatos: {'prio': 'alcance', 'type': 'table', 'page': 54, 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS"}', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '54_3'}
# KV dict: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS'}
#
# --- CHUNK INVENTARIO ---
# SKID. -INSTALACIÓN DE CABLEADOS INTERNOS DE ELÉCTRICIDAD E INSTRUMENTACIÓN, ASÍ COMO INTERCONEXIONES DE LOS EQUIPOS ROTATIVOS Y ESTÁTICOS QUE INTEGRAN EL SKID. -SISTEMA DE CONTROL LOCAL DEL SKID, QUE CUENTEN CON PUERTOS DE FIBRA ÓPTICA Y PROTOCOLO MODBUS TCP/IP PARA COMUNICACIÓN CON EL SISTEMA DE CONTROL DEL STAP EC3; CONTROLADOR PCS-009. 2. DE ACUERDO A INFORMACIÓN DEL PROVEEDOR DEL SKID DE QUÍMI
# Metadatos: {'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS"}', 'page': 54, 'chunk_id': '54_3', 'prio': 'alcance'}
# KV dict: {'caudal_gph': '18', 'presion_psig': '100', 'hp_motor': '1', 'material_tanque': '304SS'}
#
# 📊 Total de chunks con KV útiles: 10

# %%
# ============================================
# Paso 14 (v3) – Alcance + Datos de diseño de la bomba API 675 (robusto + actualizado)
# ============================================
import re, json
from langchain.schema import Document

def _j(x):
    try:
        return json.loads(x)
    except Exception:
        return {}

def _parse_nums(text: str):
    """Extrae caudal (GPH), presión (psig) y HP desde texto libre (fallback)."""
    caudal = None
    pres = None
    hp = None

    # Caudal "12 - 18 GPH" | "12–18 Gph" | "12 a 18 GPH" | simple "18 GPH"
    m = re.search(r'(\d+(?:[.,]\d+)?)\s*(?:-|–|a|to)\s*(\d+(?:[.,]\d+)?)\s*(gph|g\.?p\.?h\.?)\b', text, re.I)
    if m:
        caudal = f"{m.group(1)} - {m.group(2)}"
    else:
        m = re.search(r'\b(\d+(?:[.,]\d+)?)\s*(gph|g\.?p\.?h\.?)\b', text, re.I)
        if m:
            caudal = m.group(1)

    # Presión "@ 100 psi" | "100 psig"
    m = re.search(r'@?\s*(\d+(?:[.,]\d+)?)\s*(psi|psig)\b', text, re.I)
    if m:
        pres = m.group(1)

    # Potencia "1 HP"
    m = re.search(r'\b(\d+(?:[.,]\d+)?)\s*hp\b', text, re.I)
    if m:
        hp = m.group(1)

    return caudal, pres, hp

def prueba_alcance_y_datos_bomba_v3():
    q_alc = "alcance del suministro paquete de inyección de químicos"
    q_hd  = "bomba dosificadora API 675 caudal presión HP materiales GPH psig"

    # 1) Recuperar alcance
    retr_alc = vectorstore.as_retriever(
        search_kwargs={"k": 12, "filter": {"prio": "alcance"}},
        search_type="mmr"
    )
    alc_docs = retr_alc.get_relevant_documents(q_alc)

    if not alc_docs:  # fallback
        retr_alc_fb = vectorstore.as_retriever(search_kwargs={"k": 12}, search_type="mmr")
        alc_docs = retr_alc_fb.get_relevant_documents("alcance del suministro")

    # 2) Recuperar hojas de datos
    retr_hd = vectorstore.as_retriever(
        search_kwargs={"k": 20, "filter": {"prio": "hoja_datos"}},
        search_type="mmr"
    )
    hd_docs = retr_hd.get_relevant_documents(q_hd)

    # 3) Refuerzo directo desde la colección (KV + texto clave)
    coll = vectorstore._collection
    meta_hd = coll.get(where={"prio": "hoja_datos"}, include=["metadatas", "documents"])
    for md, doc in zip(meta_hd["metadatas"], meta_hd["documents"]):
        if not isinstance(md, dict):
            continue
        if ("kv" in md and any(k in md["kv"] for k in ["caudal_gph", "presion_psig", "hp_motor", "material_tanque", "material_mojado", "bombas_operativas", "bombas_respaldo"])) \
           or ("API 675" in (doc or "") or "GPH" in (doc or "") or "psig" in (doc or "")):
            hd_docs.append(Document(page_content=doc, metadata=md))

    # 4) De-duplicar por (page,type,primeros 60 chars)
    def _key(d): return (d.metadata.get("page"), d.metadata.get("type"), (d.page_content or "")[:60])
    seen = set()
    alc_unique, hd_unique = [], []
    for d in alc_docs:
        k = _key(d)
        if k not in seen:
            seen.add(k); alc_unique.append(d)
    for d in hd_docs:
        k = _key(d)
        if k not in seen:
            seen.add(k); hd_unique.append(d)

    # 5) Extraer KV + regex → síntesis
    datos = {
        "caudal_gph": None,
        "presion_psig": None,
        "hp_motor": None,
        "materiales": set(),
        "api_675": False,
        "bombas_operativas": None,
        "bombas_respaldo": None,
        "paginas_fuente": set(),
    }

    for d in hd_unique:
        md = d.metadata or {}
        if "page" in md:
            datos["paginas_fuente"].add(md["page"])

        # KV directo
        if "kv" in md:
            kv = _j(md["kv"])
            if not datos["caudal_gph"] and kv.get("caudal_gph"):
                datos["caudal_gph"] = kv["caudal_gph"]
            if not datos["presion_psig"] and kv.get("presion_psig"):
                datos["presion_psig"] = kv["presion_psig"]
            if not datos["hp_motor"] and kv.get("hp_motor"):
                datos["hp_motor"] = kv["hp_motor"]
            if kv.get("material_tanque"):
                datos["materiales"].add(kv["material_tanque"])
            if kv.get("material_mojado"):
                datos["materiales"].add(kv["material_mojado"])
            if str(kv.get("api_675")).lower() == "true":
                datos["api_675"] = True
            if kv.get("bombas_operativas"):
                datos["bombas_operativas"] = kv["bombas_operativas"]
            if kv.get("bombas_respaldo"):
                datos["bombas_respaldo"] = kv["bombas_respaldo"]

        # Fallback regex
        if any(v is None for v in (datos["caudal_gph"], datos["presion_psig"], datos["hp_motor"])):
            c, p, h = _parse_nums(d.page_content or "")
            if c and not datos["caudal_gph"]:
                datos["caudal_gph"] = c
            if p and not datos["presion_psig"]:
                datos["presion_psig"] = p
            if h and not datos["hp_motor"]:
                datos["hp_motor"] = h

    # 6) Mostrar resultados
    print(f"🔎 ALCANCE (k={len(alc_unique)}):")
    for r in alc_unique[:5]:
        print(f"\n— p.{r.metadata.get('page')} | {r.metadata.get('type')}")
        print((r.page_content or "")[:350].replace("\n", " "))

    print(f"\n🔎 HOJA DE DATOS (k={len(hd_unique)}):")
    for r in hd_unique[:6]:
        print(f"\n— p.{r.metadata.get('page')} | {r.metadata.get('type')}")
        print((r.page_content or "")[:350].replace("\n", " "))
        if "kv" in r.metadata:
            print("KV:", r.metadata["kv"])

    print("\n✅ EXTRACCIÓN SINTETIZADA:")
    print(f"  • Caudal (GPH): {datos['caudal_gph']}")
    print(f"  • Presión (psig): {datos['presion_psig']}")
    print(f"  • Potencia (HP): {datos['hp_motor']}")
    print(f"  • Materiales: {', '.join(sorted(datos['materiales'])) or '—'}")
    print(f"  • API 675: {'Sí' if datos['api_675'] else 'N/D'}")
    print(f"  • Bombas operativas: {datos['bombas_operativas'] or '—'}")
    print(f"  • Bombas respaldo: {datos['bombas_respaldo'] or '—'}")
    print(f"  • Páginas fuente (HD): {sorted(datos['paginas_fuente'])}")

    return {"alcance": alc_unique, "hoja_datos": hd_unique, "datos": datos}

# Ejecución:
prueba_alcance_y_datos_bomba_v3()
# Out:
# 🔎 ALCANCE (k=8):
#
# — p.1 | text
# MAYORES PAQUETES DE INYECCIÓN DE QUÍMICOS
#
# — p.18 | text
# MAYORES PAQUETES DE INYECCIÓN DE QUÍMICOS
#
# — p.25 | text
# MAYORES PAQUETES DE INYECCIÓN DE QUÍMICOS
#
# — p.26 | text
# MAYORES PAQUETES DE INYECCIÓN DE QUÍMICOS
#
# — p.2 | text
# MAYORES PAQUETES DE INYECCIÓN DE QUÍMICOS
#
# 🔎 HOJA DE DATOS (k=106):
#
# — p.43 | text
# 96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El paquete contara con un sistema
# KV: {"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}
#
# — p.42 | table
# (GPH) | | MODELO | RANGO (Cps) | POTENCIA MOTOR ELECTRICO (hp) (NOTA 15) | CANTIDAD 20 21 22 23 24 25 26 27 28 | STAP EC3 (NOTA 18) AFC4 | Se requiere una unidad paquete de Preparación y Dosificación sobre patín, conformada al menos por: Un tanque horizontal de 1056 galones de acero inoxidable 304ss con dos cámaras de preparación, y una camara para
# KV: {"caudal_gph": "12-18", "presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "rango_cps_min": "500", "rango_cps_max": "1000", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}
#
# — p.42 | table
# PROVEEDOR (NOTA 16) | | PROVEEDOR | 1 | 18 GPH @ 100 psi Una (1) Bomba operativas + Una (1) Bomba de Respaldo. | | PROVEEDOR | 500 - 1000Cps PROVEEDOR (NOTA 16) | 1 Hp | 1 + 1 29 | MATERIALES BOMBA | | | | | | | | | | | | | | | | | | | |  30 31 32 | PARTES | | TIPO DE QUÍMICO | | | | | | | | | | | | | | | | | |   | | | POLIMERO ANIÓNICO PARA RETROL
# KV: {"caudal_gph": "12-18", "presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "rango_cps_min": "500", "rango_cps_max": "1000", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}
#
# — p.32 | table
# | | | | Descripción | Código de Catálogo ECOPETROL Ítem | Cantidad | Unidad | TAG | |  1 | 1 | UND | AX- 75317 | Patín de Preparación y Dosificación: Se requiere una unidad paquete de Preparación y Dosificación montada sobre patín, conformada al menos por: Un tanque tipo horizontal de 1056 galones de acero inoxidable 304ss. Este paquete también inc
# KV: {"caudal_gph": "12-18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}
#
# — p.42 | table
# introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El paquete contara con un sistema de control PLC ded
# KV: {"caudal_gph": "18", "presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "rango_cps_min": "500", "rango_cps_max": "1000", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}
#
# — p.6 | text
# MAYORES PAQUETES DE INYECCIÓN DE QUÍMICOS
# KV: {"material_tanque": "304SS", "api_675": "true"}
#
# ✅ EXTRACCIÓN SINTETIZADA:
#   • Caudal (GPH): 18
#   • Presión (psig): 100
#   • Potencia (HP): 1
#   • Materiales: 304SS, 316SS
#   • API 675: Sí
#   • Bombas operativas: 1
#   • Bombas respaldo: 1
#   • Páginas fuente (HD): [6, 9, 17, 20, 32, 37, 38, 42, 43, 61, 67, 68]
# {'alcance': [Document(metadata={'page': 1, 'prio': 'alcance', 'chunk_id': '1_1', 'type': 'text', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}, page_content='MAYORES\nPAQUETES DE INYECCIÓN DE QUÍMICOS'),
#   Document(metadata={'page': 18, 'type': 'text', 'chunk_id': '18_1', 'prio': 'alcance', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}, page_content='MAYORES\nPAQUETES DE INYECCIÓN DE QUÍMICOS'),
#   Document(metadata={'type': 'text', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'alcance', 'page': 25, 'chunk_id': '25_1'}, page_content='MAYORES\nPAQUETES DE INYECCIÓN DE QUÍMICOS'),
#   Document(metadata={'type': 'text', 'page': 26, 'prio': 'alcance', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '26_1'}, page_content='MAYORES\nPAQUETES DE INYECCIÓN DE QUÍMICOS'),
#   Document(metadata={'prio': 'alcance', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 2, 'type': 'text', 'chunk_id': '2_1'}, page_content='MAYORES\nPAQUETES DE INYECCIÓN DE QUÍMICOS'),
#   Document(metadata={'type': 'text', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'alcance', 'page': 3, 'chunk_id': '3_1'}, page_content='MAYORES\nPAQUETES DE INYECCIÓN DE QUÍMICOS'),
#   Document(metadata={'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'alcance', 'page': 19, 'chunk_id': '19_1', 'type': 'text'}, page_content='MAYORES\nPAQUETES DE INYECCIÓN DE QUÍMICOS'),
#   Document(metadata={'page': 31, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'alcance', 'chunk_id': '31_1', 'type': 'text'}, page_content='MAYORES\nPAQUETES DE INYECCIÓN DE QUÍMICOS')],
#  'hoja_datos': [Document(metadata={'prio': 'hoja_datos', 'page': 43, 'type': 'text', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'chunk_id': '43_3', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}, page_content='96 2 agua, para la introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la dosificacion debe contar con Una (1) bomba dosificadora de diafragma para la inyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con una (1) de respaldo accionadas por motores eléctricos. El\npaquete contara con un sistema de control PLC dedicado a gestionar todas las funciones del paquete, sus cajas (Potencia, Instrumentación, Instrumentos y Control NEMA 4X (Área no clasificada). La instrumentación mínima asociada al paquete está indicada en el P&ID CAS-09991-PRO-PID-000012 - STAP EC3.\n97'),
#   Document(metadata={'type': 'table', 'chunk_id': '42_4', 'kv': '{"caudal_gph": "12-18", "presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "rango_cps_min": "500", "rango_cps_max": "1000", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}', 'page': 42, 'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}, page_content='(GPH) | | MODELO | RANGO\n(Cps) | POTENCIA\nMOTOR\nELECTRICO\n(hp)\n(NOTA 15) | CANTIDAD\n20\n21\n22\n23\n24\n25\n26\n27\n28 | STAP\nEC3\n(NOTA 18)\nAFC4 | Se requiere una unidad paquete de Preparación y Dosificación sobre patín,\nconformada al menos por: Un tanque horizontal de 1056 galones de acero inoxidable\n304ss con dos cámaras de preparación, y una camara para dosificación. Este paquete\ntambién incluye un sistema de control automático para la entrada de agua, para la\nintroducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la\ndosificacion debe contar con una (1) bomba dosificadora de diafragma para la\ninyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con\nuna (1) de respaldo accionadas por motores eléctricos. El paquete contara con un'),
#   Document(metadata={'type': 'table', 'page': 42, 'chunk_id': '42_6', 'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'kv': '{"caudal_gph": "12-18", "presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "rango_cps_min": "500", "rango_cps_max": "1000", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}'}, page_content='PROVEEDOR\n(NOTA 16) | | PROVEEDOR | 1 | 18 GPH @ 100 psi\nUna (1) Bomba operativas + Una\n(1) Bomba de Respaldo. | | PROVEEDOR | 500 - 1000Cps\nPROVEEDOR\n(NOTA 16) | 1 Hp | 1 + 1\n29 | MATERIALES BOMBA | | | | | | | | | | | | | | | | | | | | \n30\n31\n32 | PARTES | | TIPO DE QUÍMICO | | | | | | | | | | | | | | | | | | \n | | | POLIMERO ANIÓNICO PARA RETROLAVADOS | | | | | | | | | | | | | | | | | | \n | LIQUID END | | Stainless Steel | | | | | | | | | | | | | | | | | | \n33\n34\n35\n36\n37\n43 | CONTOUR PLATE | | POR PROVEEDOR | | | | | | | | | | | | | | | | | | \n | HYDRAULIC DIAPHRAGM | | Solid PTFE | | | | | | | | | | | | | | | | | | \n | PLUNGER | | POR PROVEEDOR | | | | | | | | | | | | | | | | | | \n | FRAME | | POR PROVEEDOR | | | | | | | | | | | | | | | | | |'),
#   Document(metadata={'page': 32, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '32_1', 'type': 'table', 'kv': '{"caudal_gph": "12-18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'prio': 'hoja_datos'}, page_content='| | | | Descripción | Código de\nCatálogo\nECOPETROL\nÍtem | Cantidad | Unidad | TAG | | \n1 | 1 | UND | AX-\n75317 | Patín de Preparación y Dosificación: Se requiere\nuna unidad paquete de Preparación y Dosificación montada\nsobre patín, conformada al menos por: Un tanque tipo\nhorizontal de 1056 galones de acero inoxidable 304ss. Este\npaquete también incluye un sistema de control automático\npara la entrada de agua (100 gpm), sistema de agitación\nmecánica, alarma para vaciado y llenado. para la\ndosificación debe contar con una (1) bomba dosificadora de\ndiafragma para la inyección de polímero líquido preparado\nde 1HP, capacidad de 12 - 18 Gph @ 100psi, API 675, con\nuna (1) de respaldo accionadas por motores eléctricos. | N.A.'),
#   Document(metadata={'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 42, 'prio': 'hoja_datos', 'type': 'table', 'chunk_id': '42_4', 'kv': '{"caudal_gph": "18", "presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "rango_cps_min": "500", "rango_cps_max": "1000", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}'}, page_content='introducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la\ndosificacion debe contar con una (1) bomba dosificadora de diafragma para la\ninyección de polímero líquido preparado de 1Hp,12 - 18 gph @ 100psi, API 675, con\nuna (1) de respaldo accionadas por motores eléctricos. El paquete contara con un\nsistema de control PLC dedicado a gestionar todas las funciones del paquete, sus\ncajas (Potencia, Instrumentación, Instrumentos y Control NEMA 4X. Las bombas\ndosificaran químico aniónico hacia el patín de almacenamiento Tanques de\nDecantación ATR-7551 A/B/C/D/E/F Cabezal de Línea 8"-PWA-751407-AA1A33-01-\nN-0.0"\nEl PLC deberá contar con modulos de comunicación modbus TCP/IJP con pupertos\nRJ45 y de friba optica | POLIMERO\nANIÓNICO\nLIQUIDO.\nAutonomia dos (2)\ndías\nPOLIMERO'),
#   Document(metadata={'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'text', 'chunk_id': '6_1', 'page': 6, 'prio': 'hoja_datos', 'kv': '{"material_tanque": "304SS", "api_675": "true"}'}, page_content='MAYORES\nPAQUETES DE INYECCIÓN DE QUÍMICOS'),
#   Document(metadata={'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'hoja_datos', 'type': 'text', 'kv': '{"material_tanque": "304SS", "api_675": "true"}', 'chunk_id': '6_2', 'page': 6}, page_content='VICEPRESIDENCIA DE INGENIERÍA Y PROYECTOS\nCÓDIGO Elaborado\nVersión: 1\nEDP-F-046 20/11/2017\nMR #:\nINGENIERÍA DETALLADA ESTACIONES MÓDULO\nCAS-09991-MER-MR- REV: 4\nINTEGRAL\n000003\nDocumento:\nRequisición de Materiales FECHA:\nEspecialidad Mecánica\nPaquete de inyección de 14/11/2024\nquímicos\nCOMPRADOR por escrito de los conflictos identificados para su resolución, los cuales deben quedar\nresueltos en la KOM (Reunión de inicio), cuando aplique.\n2. ALCANCE DEL SUMINISTRO\n2.1. ALCANCE GENERAL\nUnidad tipo paquete de inyección de químicos y de los quill de inyección roscados; el alcance del\nsuministro de cada ítem incluido en esta requisición de materiales debe cumplir con todos los requisitos\nestablecidos en la misma y en sus respectivos anexos.\nCódigo de'),
#   Document(metadata={'chunk_id': '6_3', 'type': 'text', 'kv': '{"material_tanque": "304SS", "api_675": "true"}', 'page': 6, 'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}, page_content='establecidos en la misma y en sus respectivos anexos.\nCódigo de\nÍtem Cantidad Unidad TAG Descripción Catálogo\nECOPETROL\nPatín de Preparación y Dosificación: Se requiere una\nunidad paquete de Preparación y Dosificación sobre patín,\nconformada al menos por: Un tanque horizontal de 1056\ngalones de acero inoxidable 304ss con dos cámaras de\npreparación, y una cámara para dosificación. Este paquete\ntambién incluye un sistema de control automático, para la\ndosificación debe contar con una (1) bomba dosificadora de\ndiafragma para la inyección de polímero líquido preparado\nAPI 675, con una (1) de respaldo.\nAX-\n1 1 UND N.A.\n75317 El paquete debe contar con un sistema de control PLC\n4\ndedicado a gestionar todas las funciones del paquete, NEMA\n4X.'),
#   Document(metadata={'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'kv': '{"material_tanque": "304SS", "api_675": "true"}', 'prio': 'hoja_datos', 'chunk_id': '6_4', 'type': 'text', 'page': 6}, page_content='4\ndedicado a gestionar todas las funciones del paquete, NEMA\n4X.\nLas bombas dosificarán polimero aniónico hacia el patín de\nalmacenamiento Tanques de Decantación ATR-7551\nA/B/C/D/E/F Cabezal de Línea 8"-PWA-751407-AA1A33-\n01-N-0.0".\nRef P&ID: CAS-01236-PRO-PID-000001\nSuministro de un (1) quill de inyección retráctil (boquilla\nAX- de inyección retráctil) con kit de aislamiento. Inyección de\n4 2 1 UND N.A\n75317 polímero aniónico. P&ID CAS-01236-PRO-PID-000001. 8”-\nPWA-751407-AA1A33-01-N-0.0”\nEDP-F-046 – 20/11/2017 V-1 6/36\nDocumento Rector: EDP-G-009'),
#   Document(metadata={'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '6_5', 'type': 'text', 'page': 6, 'prio': 'hoja_datos', 'kv': '{"material_tanque": "304SS", "api_675": "true"}'}, page_content='puede ser hecha sin permiso escrito. Ningún párrafo de esta publicación puede ser reproducido, copiado o transmitido\ndigitalmente sin un consentimiento escrito o de acuerdo con las leyes que regulan los derechos de autor y con base en la\nregulación vigente.'),
#   Document(metadata={'prio': 'hoja_datos', 'kv': '{"material_tanque": "304SS", "api_675": "true"}', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'table', 'chunk_id': '6_1', 'page': 6}, page_content='Ítem | Cantidad | Unidad | TAG | Descripción | Código de\nCatálogo\nECOPETROL\n1 | 1 | UND | AX-\n75317 | Patín de Preparación y Dosificación: Se requiere una\nunidad paquete de Preparación y Dosificación sobre patín,\nconformada al menos por: Un tanque horizontal de 1056\ngalones de acero inoxidable 304ss con dos cámaras de\npreparación, y una cámara para dosificación. Este paquete\ntambién incluye un sistema de control automático, para la\ndosificación debe contar con una (1) bomba dosificadora de\ndiafragma para la inyección de polímero líquido preparado\nAPI 675, con una (1) de respaldo.\nEl paquete debe contar con un sistema de control PLC\ndedicado a gestionar todas las funciones del paquete, NEMA\n4X.\nLas bombas dosificarán polimero aniónico hacia el patín de'),
#   Document(metadata={'kv': '{"material_tanque": "304SS", "api_675": "true"}', 'page': 6, 'type': 'table', 'prio': 'hoja_datos', 'chunk_id': '6_2', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}, page_content='4X.\nLas bombas dosificarán polimero aniónico hacia el patín de\nalmacenamiento Tanques de Decantación ATR-7551\nA/B/C/D/E/F Cabezal de Línea 8"-PWA-751407-AA1A33-\n01-N-0.0".\nRef P&ID: CAS-01236-PRO-PID-000001 | N.A.\n2 | 1 | UND | AX-\n75317 | Suministro de un (1) quill de inyección retráctil (boquilla\nde inyección retráctil) con kit de aislamiento. Inyección de\npolímero aniónico. P&ID CAS-01236-PRO-PID-000001. 8”-\nPWA-751407-AA1A33-01-N-0.0” | N.A'),
#   Document(metadata={'type': 'text', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 9, 'kv': '{"api_675": "true"}', 'chunk_id': '9_3', 'prio': 'hoja_datos'}, page_content='y para su manejo en el sitio de la obra.\nEn el evento que hubiese algún daño en el material o equipo transportado, el PROVEEDOR debe reparar\nel daño y asumir todos los costos, incluyendo los de transporte, aún en el caso en que la Compañía de\nSeguros se niegue a reconocer tales costos.\nINGENIERÍA\n• Diseño y selección de equipos bajo requerimientos de la normativa API 675 y las condiciones de\noperación indicadas en los documentos anexos a la presente MR, para las bombas dosificadoras de\ncada PAQUETE de inyección de químicos, como se indica en el numeral 2.1.\n• Selección con criterios de ingeniería y según normativa de diseño de los tanques de almacenamiento,\naccesorios y la instrumentación que hacen parte del PAQUETE y que son requeridos para garantizar\nuna operación confiable y segura.'),
#   Document(metadata={'kv': '{"api_675": "true"}', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '17_4', 'type': 'text', 'prio': 'hoja_datos', 'page': 17}, page_content='• 1.2 POSITIVE DISPLACEMENT PUMPS\n• 1.2.2 METERING PUMPS (Norma API 675)\n• 3.1 MANUAL VALVES\n• 6.13.1 TUBING & FITTINGS (TUBING ACCESSORIES)\nTodos los instrumentos y equipos suministrados con el PAQUETE deben estar de acuerdo con la Lista de\nMarcas homologadas por ECOPETROL en su ultima revisión.\n4.7. PROVEEDORES HOMOLOGADOS DE ECOPETROL\nAplica Proveedores Homologados de ECOPETROL: N/A.\nCategoría (s) Proveedores Homologados ECOPETROL: N/A.\n4.8. REUNIONES DE INGENIERÍA Y VISITAS\nDe acuerdo con el plan de inspección y pruebas (ITP) y el nivel de inspección para este equipo, debe\nhaber como mínimo las siguientes visitas y reuniones:\nEDP-F-046 – 20/11/2017 V-1 17/36\nDocumento Rector: EDP-G-009'),
#   Document(metadata={'prio': 'hoja_datos', 'type': 'text', 'kv': '{"material_tanque": "304SS"}', 'page': 20, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '20_1'}, page_content='MAYORES\nPAQUETES DE INYECCIÓN DE QUÍMICOS'),
#   Document(metadata={'type': 'text', 'kv': '{"material_tanque": "304SS"}', 'chunk_id': '20_2', 'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 20}, page_content='VICEPRESIDENCIA DE INGENIERÍA Y PROYECTOS\nCÓDIGO Elaborado\nVersión: 1\nEDP-F-046 20/11/2017\nMR #:\nINGENIERÍA DETALLADA ESTACIONES MÓDULO\nCAS-09991-MER-MR- REV: 4\nINTEGRAL\n000003\nDocumento:\nRequisición de Materiales FECHA:\nEspecialidad Mecánica\nPaquete de inyección de 14/11/2024\nquímicos\nToda la documentación se debe entregar como mínimo en la forma y cantidad indicada en el numeral\n4.3 y 4.4 de esta MR.\nLa documentación se debe entregar en español, en caso de que el PROVEEDOR de los equipos emita\ndocumentos y planos en inglés solo se aceptan si son documentos originales de este. Los manuales de\noperación y mantenimiento deben ser suministrados en su totalidad en idioma español.\nSe deberá usar la última edición o adenda de los estándares y códigos de diseño mencionados en la'),
#   Document(metadata={'kv': '{"material_tanque": "304SS"}', 'prio': 'hoja_datos', 'type': 'text', 'chunk_id': '20_3', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 20}, page_content='Se deberá usar la última edición o adenda de los estándares y códigos de diseño mencionados en la\npresente requisición al momento de realizar la compra.\nEl PROVEEDOR también debe cumplir con los requerimientos presentados en el documento referenciado\nen esta requisición de materiales.\nEs responsabilidad del PROVEEDOR solicitar los documentos listados en la sección 10.3 de este\ndocumento, o cualquier otro documento que pudieron haber sido omitidos sin intención por parte de\nECOPETROL y que sea requerido para la ejecución de los trabajos.\n• La codificación y formatos para la presentación de los documentos elaborados por el PROVEEDOR\npara la fabricación de los equipos deberá ser revisado y acordado con ECOPETROL durante el\nproceso de cotización y formalizado en la reunión de inicio (KOM).'),
#   Document(metadata={'type': 'text', 'chunk_id': '20_4', 'page': 20, 'kv': '{"material_tanque": "304SS"}', 'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}, page_content='proceso de cotización y formalizado en la reunión de inicio (KOM).\n5. REQUERIMIENTOS TÉCNICOS\n5.1. REQUERIMIENTOS MECÁNICOS\nEstos requerimientos se consignan en los documentos mecánicos que acompaña esta requisición:\n• CAS-09991-MER-HD-000003 Hoja de Datos de Paquete de Química STAP EC3.\nCada equipo que conforma cada PAQUETE debe ser suministrado con una placa de identificación en\nacero inoxidable SS-304 y con un espesor mínimo de 1/16in (1.5mm), ubicada en un lugar visible y\nunida a cada equipo de forma permanente, la información debe ser incluida en idioma español, no se\nadmite letras pintadas, deben ser grabadas o estampadas sobre la lámina.\nLa placa debe contener como mínimo:\n• Nombre del PROVEEDOR.\n• Número de serie de EL PROVEEDOR.\n• Año de Fabricación.\n• Número del equipo (Tag).'),
#   Document(metadata={'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'kv': '{"material_tanque": "304SS"}', 'chunk_id': '20_5', 'page': 20, 'prio': 'hoja_datos', 'type': 'text'}, page_content='• Número de serie de EL PROVEEDOR.\n• Año de Fabricación.\n• Número del equipo (Tag).\nEDP-F-046 – 20/11/2017 V-1 20/36\nDocumento Rector: EDP-G-009'),
#   Document(metadata={'type': 'text', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '20_6', 'prio': 'hoja_datos', 'kv': '{"material_tanque": "304SS"}', 'page': 20}, page_content='puede ser hecha sin permiso escrito. Ningún párrafo de esta publicación puede ser reproducido, copiado o transmitido\ndigitalmente sin un consentimiento escrito o de acuerdo con las leyes que regulan los derechos de autor y con base en la\nregulación vigente.'),
#   Document(metadata={'prio': 'hoja_datos', 'chunk_id': '32_1', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'text', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'page': 32}, page_content='MAYORES\nPAQUETES DE INYECCIÓN DE QUÍMICOS'),
#   Document(metadata={'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '32_2', 'type': 'text', 'page': 32, 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'prio': 'hoja_datos'}, page_content='VICEPRESIDENCIA DE INGENIERÍA Y PROYECTOS\nCÓDIGO Elaborado\nVersión: 1\nEDP-F-046 20/11/2017\nMR #:\nINGENIERÍA DETALLADA ESTACIONES MÓDULO\nCAS-09991-MER-MR- REV: 4\nINTEGRAL\n000003\nDocumento:\nRequisición de Materiales FECHA:\nEspecialidad Mecánica\nPaquete de inyección de 14/11/2024\nquímicos\nTodos los equipos componentes del paquete de inyección de químicos, así como los componentes de los\nquill´s de inyección retráctiles deben ser diseñados y seleccionados para una vida útil de 20 años.\nEl VENDEDOR debe expedir una carta de garantía para el paquete de inyección de químicos, los quill´s\nde inyección retráctiles y sus componentes, que cubra cualquier defecto de fabricación y/o desempeño;\nválida por doce (12) meses, contados a partir de la fecha de puesta en funcionamiento del equipo y sus'),
#   Document(metadata={'type': 'text', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 32, 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'chunk_id': '32_3', 'prio': 'hoja_datos'}, page_content='componentes, o dieciocho (18) meses a partir de la entrega a satisfacción de estos por parte de\nECOPETROL S.A. Durante este período la garantía debe cubrir la reparación o reemplazo de los\ncomponentes defectuosos por parte del VENDEDOR incluyendo todas las labores, equipos, transporte y\ndemás costos generados y requeridos para llevar a cabo dicha reparación y/o reemplazo.\n10. ANEXOS\n10.1. LISTA DEL ALCANCE:\nEl PROVEEDOR no debe limitarse a la lista indicada a continuación, es su responsabilidad entregar un\nequipo completo, probado, funcional y listo para instalación cumpliendo con las condiciones\noperacionales indicadas en la hoja de datos y demás documentos que hacen parte de esta requisición.'),
#   Document(metadata={'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'text', 'page': 32, 'chunk_id': '32_4', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}'}, page_content='operacionales indicadas en la hoja de datos y demás documentos que hacen parte de esta requisición.\nEl paquete de inyección de químicos, los quill´s de inyección retráctiles deberán ser suministrados y\ngarantizado como una unidad completa por un sólo PROVEEDOR, de acuerdo con los requerimientos\nincluidos en este documento. El paquete de inyección de químicos y los quill´s de inyección retráctiles\ndeben ser suministrados con todos los accesorios necesarios para su operación satisfactoria incluyendo,\npero no estando limitado a:\nCódigo de\nÍtem Cantidad Unidad TAG Descripción Catálogo\nECOPETROL\nPatín de Preparación y Dosificación: Se requiere\nuna unidad paquete de Preparación y Dosificación montada\nsobre patín, conformada al menos por: Un tanque tipo'),
#   Document(metadata={'page': 32, 'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'type': 'text', 'chunk_id': '32_5'}, page_content='sobre patín, conformada al menos por: Un tanque tipo\nhorizontal de 1056 galones de acero inoxidable 304ss. Este\npaquete también incluye un sistema de control automático\nAX- para la entrada de agua (100 gpm), sistema de agitación\n1 1 UND N.A.\n75317 mecánica, alarma para vaciado y llenado. para la\n4\ndosificación debe contar con una (1) bomba dosificadora de\ndiafragma para la inyección de polímero líquido preparado\nde 1HP, capacidad de 12 - 18 Gph @ 100psi, API 675, con\nuna (1) de respaldo accionadas por motores eléctricos.\nEDP-F-046 – 20/11/2017 V-1 32/36\nDocumento Rector: EDP-G-009'),
#   Document(metadata={'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'type': 'text', 'page': 32, 'prio': 'hoja_datos', 'chunk_id': '32_6', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}, page_content='puede ser hecha sin permiso escrito. Ningún párrafo de esta publicación puede ser reproducido, copiado o transmitido\ndigitalmente sin un consentimiento escrito o de acuerdo con las leyes que regulan los derechos de autor y con base en la\nregulación vigente.'),
#   Document(metadata={'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '32_1', 'kv': '{"caudal_gph": "18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'prio': 'hoja_datos', 'page': 32, 'type': 'table'}, page_content='Descripción | Código de\nCatálogo\nECOPETROL\nÍtem | Cantidad | Unidad | TAG\n1 | 1 | UND | AX-\n75317 | Patín de Preparación y Dosificación: Se requiere\nuna unidad paquete de Preparación y Dosificación montada\nsobre patín, conformada al menos por: Un tanque tipo\nhorizontal de 1056 galones de acero inoxidable 304ss. Este\npaquete también incluye un sistema de control automático\npara la entrada de agua (100 gpm), sistema de agitación\nmecánica, alarma para vaciado y llenado. para la\ndosificación debe contar con una (1) bomba dosificadora de\ndiafragma para la inyección de polímero líquido preparado\nde 1HP, capacidad de 12 - 18 Gph @ 100psi, API 675, con\nuna (1) de respaldo accionadas por motores eléctricos. | N.A.'),
#   Document(metadata={'prio': 'hoja_datos', 'type': 'text', 'page': 37, 'chunk_id': '37_7', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}, page_content='22 Clasificación del área NO Area No Clasificada\n23 Equipo apto para Intemperie? SI SI\n24 Fluido de operación SI Agua Filtrada\n25 Temperatura de bombeo T.B. (°F) NO -\n26 Densidad relativa @ T.B. NO -\n27 Viscosidad @ T.B. (cP) SI 500-1000\n28 Presión de vapor @ T.B. (Psia) NO -\n29 Presión de succión (psig) NO -\n30 Presión de descarga (psig) SI 100\n31 Presión diferencial @ impulsor nominal (psi) NO -\n32 Capacidad normal (gph) SI\n33 Capacidad máx. (gph) SI 18\n34 Capacidad a min. Flujo estable. (gpm) NO -\n35 Región de operación permitida (gph) SI 12 - 18\n36 Punto de mejor eficiencia @ impulsor nominal (gpm) NO -\n37 Potencia hidráulica (HHP) NO -\n38 Potencia al freno (BHP) NO -\n39 Potencia nominal (HP) SI 1\n40 Eficiencia (%) SI ≥80'),
#   Document(metadata={'page': 37, 'chunk_id': '37_7', 'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'table'}, page_content='22 | Clasificación del área | NO | Area No Clasificada\n23 | Equipo apto para Intemperie? | SI | SI\n24 | Fluido de operación | SI | Agua Filtrada\n25 | Temperatura de bombeo T.B. (°F) | NO | -\n26 | Densidad relativa @ T.B. | NO | -\n27 | Viscosidad @ T.B. (cP) | SI | 500-1000\n28 | Presión de vapor @ T.B. (Psia) | NO | -\n29 | Presión de succión (psig) | NO | -\n30 | Presión de descarga (psig) | SI | 100\n31 | Presión diferencial @ impulsor nominal (psi) | NO | -\n32 | Capacidad normal (gph) | SI\n33 | Capacidad máx. (gph) | SI | 18\n34 | Capacidad a min. Flujo estable. (gpm) | NO | -\n35 | Región de operación permitida (gph) | SI | 12 - 18\n36 | Punto de mejor eficiencia @ impulsor nominal (gpm) | NO | -\n37 | Potencia hidráulica (HHP) | NO | -\n38 | Potencia al freno (BHP) | NO | -'),
#   Document(metadata={'prio': 'hoja_datos', 'page': 38, 'type': 'text', 'kv': '{"api_675": "true"}', 'chunk_id': '38_1', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}, page_content='41 Velocidad de giro (RPM) NO -\n42 S ane tn ihti od ro a rd ioe ) giro visto desde el extremo del acople (horario/ SI CW\n43 Consumo energético (Kw/h) NO -\nOtros requerimientos\nLos equipos de bombeo ofertados cumplen con las condiciones de\n44 operación y con las condiciones del fluido señaladas en la HD del SI -\ndocumentoCAS-09991-MER-HD-000003?\nMecánica\nCaracterísticas técnicas\n45 Código de diseño bomba SI API 675\n46 Modelo NO\n47 Tamaño NO\n48 Tipo de bomba SI Controlled volume, positive displacement\n49 Número de etapas NO\n50 Tipo de impulsor (Cerrado / abierto) NO\nLubricación\n51 Tipo de lubricación (indicar descripción) NO\n52 Incluye bomba (indicar descripción) NO -\n53 Incluye deposito de aceite (indicar descripción) NO -\n54 Incluye filtrado en succión (indicar descripción) NO -'),
#   Document(metadata={'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 38, 'kv': '{"api_675": "true"}', 'chunk_id': '38_2', 'prio': 'hoja_datos', 'type': 'text'}, page_content='54 Incluye filtrado en succión (indicar descripción) NO -\n55 Incluye sistema de enfriamiento (indicar descripción) NO -\nSello mecánico\n56 Código de fabricación sello NO -\n57 Tipo de sello mecánico NO -\n58 Fabricante (cumple marca homologada?) NO -\n59 Modelo sello NO -\n60 Plan de sellado (API) NO -\n61 Máxima presión de trabajo (psig) NO -\n62 Máx. Temperatura de operación (°F) NO -\n63 Materiales - partes principales del sello NO -\nAcople\n64 Tipo de acople NO -\n65 Fabricante del acople NO -\n66 Código de fabricación SI API 675\n67 Factor de servicio NO -\n68 Guarda acople antichispa NO -\n69 Amortiguamiento en el acople NO -\nRodamientos\n70 Rodamiento axial NO -\n71 Rodamiento radial NO -\nMateriales\n72 Carcasa SI -\n73 Difusor SI -\n74 Impulsor SI -\n75 Eje SI -\n76 Guarda acople NO -'),
#   Document(metadata={'chunk_id': '38_1', 'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'table', 'kv': '{"api_675": "true"}', 'page': 38}, page_content='41 | Velocidad de giro (RPM) | NO | -\n42 | Sentido de giro visto desde el extremo del acople (horario/\nantihorario) | SI | CW\n43 | Consumo energético (Kw/h) | NO | -\nOtros requerimientos\n44 | Los equipos de bombeo ofertados cumplen con las condiciones de\noperación y con las condiciones del fluido señaladas en la HD del\ndocumentoCAS-09991-MER-HD-000003? | SI | -\nMecánica\nCaracterísticas técnicas\n45 | Código de diseño bomba | SI | API 675\n46 | Modelo | NO\n47 | Tamaño | NO\n48 | Tipo de bomba | SI | Controlled volume, positive displacement\n49 | Número de etapas | NO\n50 | Tipo de impulsor (Cerrado / abierto) | NO\nLubricación\n51 | Tipo de lubricación (indicar descripción) | NO\n52 | Incluye bomba (indicar descripción) | NO | -\n53 | Incluye deposito de aceite (indicar descripción) | NO | -'),
#   Document(metadata={'kv': '{"api_675": "true"}', 'prio': 'hoja_datos', 'page': 38, 'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '38_2'}, page_content='53 | Incluye deposito de aceite (indicar descripción) | NO | -\n54 | Incluye filtrado en succión (indicar descripción) | NO | -\n55 | Incluye sistema de enfriamiento (indicar descripción) | NO | -\nSello mecánico\n56 | Código de fabricación sello | NO | -\n57 | Tipo de sello mecánico | NO | -\n58 | Fabricante (cumple marca homologada?) | NO | -\n59 | Modelo sello | NO | -\n60 | Plan de sellado (API) | NO | -\n61 | Máxima presión de trabajo (psig) | NO | -\n62 | Máx. Temperatura de operación (°F) | NO | -\n63 | Materiales - partes principales del sello | NO | -\nAcople\n64 | Tipo de acople | NO | -\n65 | Fabricante del acople | NO | -\n66 | Código de fabricación | SI | API 675\n67 | Factor de servicio | NO | -\n68 | Guarda acople antichispa | NO | -\n69 | Amortiguamiento en el acople | NO | -\nRodamientos'),
#   Document(metadata={'page': 38, 'prio': 'hoja_datos', 'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'kv': '{"api_675": "true"}', 'chunk_id': '38_5'}, page_content='675? | SI\n95 | El diseño de todos los sistemas de bombeo ofertados permite el\ndesacople de equipos sin requerir la parada del proceso de\ninyección? | NO\n96 | La región preferida de las bombas ofertadas se encuentra dentro de\nlos límites establecidos en el estándar API 675? | SI\n97 | Se incluye en la oferta de las bombas la prueba de “COMPLETE\nUNIT TEST”? | NO\n98 | El NPSHR de las bombas ofertadas es al menos 3.3 pies menor al\nNPSHA? | SI\n99 | La velocidad especifica de succión de las bombas es menor a\n11.000? | NO\n100 | Se incluye dentro de la oferta de las bombas el balanceo estático y\ndinámico de todos los elementos rotatorios de la bomba? | NO\n101 | Los rodamientos ofertados para las bombas han sido diseñados\npara un ciclo de vida mínimo de 17500 horas de trabajo, para las'),
#   Document(metadata={'type': 'table', 'page': 38, 'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'kv': '{"api_675": "true"}', 'chunk_id': '38_6'}, page_content='para un ciclo de vida mínimo de 17500 horas de trabajo, para las\nregiones de 110% del flujo BEP y el mínimo flujo? | NO\n102 | Los equipos de bombeo ofertados cumplen con el grado de\ntolerancia de acuerdo API 675? | SI\n103 | Dentro de su oferta se incluye el suministro de las fuerzas y\nmomentos admisibles para todas las conexiones? | SI\n104 | Los sellos mecánicos se ofertaron tipo cartucho? | NO\n105 | Los acoples de las bombas ofertadas cumplen con el apartado 7.4\nde la ET - documento CAS-09991-MER-ET-000002?\n106 | El acople cumple con API 671? | NO\n107 | El sistema de lubricación para las bombas ofertadas cumple con el\napartado 7.6.1 de la ET - documento CAS-09991-MER-ET-\n000002? | NO\n108 | Los equipos de bombeo (bomba-motor) cumplen con el nivel de'),
#   Document(metadata={'type': 'text', 'page': 42, 'prio': 'hoja_datos', 'kv': '{"presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}', 'chunk_id': '42_1', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}, page_content='CAS-09991-MER-HD-000003\nINGENIERÍA DETALLADA ESTACIONES MÓDULO INTEGRAL\nDocumento No.\nHOJAS DE DATOS PAQUETE DE QUÍMICO STAP EC3 Revisión:AFC4\nAPLICABLE A: \uf06d PROPUESTA \uf06c COMPRA \uf06d AS BUILT\n1 CONDICIONES EN SITIO\n2 3 INSTALACIÓN \uf06d \uf06d I EN DT IE FIR CI IO OR VENTILADO \uf06d \uf06d E EDXT IFE ICR II OO R PRESURIZADO \uf06d\uf06c C INU VB EI RER NT IZA ACIÓN \uf06c \uf06c O TRN OS PH IO CR AE LIZACIÓN \uf06d \uf06d C CO ERS RTE AR MO IE N/ O TF OFSHORE\n4 ATMOSFERA \uf06d NO CORROSIVO \uf06d CORROSIVO \uf06d HUMEDAD SALINA \uf06c POLVO \uf06d VAPORES\n5 CLASIFICACIÓN ELÉCTRICA CLASE GRUPO DIVISIÓN\n6 NO CLASIFICADA (NOTA 12) OTROS CLASE GRUPO DIVISIÓN\n7 ALTITUD (ft.a.s.l) 1148 PRESIÓN ATMOSF. (psia) 14.3 TEMPERATURA AMBIEN. (ºF) 65,7 - 92,5\n8 HUMEDAD (%) 65 - 90 ZONA CLIMÁTICA TROPICAL / HÚMEDO ZONA SÍSMICA ALTA'),
#   Document(metadata={'chunk_id': '42_2', 'page': 42, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'hoja_datos', 'type': 'text', 'kv': '{"presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}'}, page_content='8 HUMEDAD (%) 65 - 90 ZONA CLIMÁTICA TROPICAL / HÚMEDO ZONA SÍSMICA ALTA\n9 FACTOR DE IMPORTANCIA (NSR 10) 1.25 FACTOR DE ZONA (NSR 10) Aa = 0,20 Av = 0,25 VEL. MÁX. VIENTO (km/h) 120\n10 CONDICIONES DE UTILIDAD\n11 VOLTAJE ELÉCTRICO (Vac/Ph/Hz) 480 VAC / 3 Ph / 60Hz VOLTAJE DE CONTROL (Vac/Ph/Hz)\nPROTOCOLO DE COMUNICACIÓN MODBUS TCP/IP PRESIÓN DE SUMINISTRO DE AIRE (psig) AIRE INSTRUMENTACIÓN 40 psig\n12 SUMINISTRO DE AGUA AFC4 100 gpm AGUA FILTRADA ( NOTA 30)\n13 CÓDIGOS DE DISEÑO Y CONSTRUCCIÓN APLICABLES (NOTA 4)\n14 \uf06c NEMA \uf06c NFPA \uf06c ANSI \uf06c AWS \uf06c NSR \uf06c OSHA \uf06c RETIE \uf06c API \uf06d OTROS:\n15 TABLA 1. DATOS DE DISEÑO DE PROCESO Y EQUIPO DE UNIDAD DE PAQUETE (NOTA 2)\n16 TANQUE DE PREPARACION BOMBAS DE DOSIFICACION CASO MEDIO\nNÓICATSE\n17 POTENCIA'),
#   Document(metadata={'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'kv': '{"presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}', 'page': 42, 'type': 'text', 'chunk_id': '42_3', 'prio': 'hoja_datos'}, page_content='16 TANQUE DE PREPARACION BOMBAS DE DOSIFICACION CASO MEDIO\nNÓICATSE\n17 POTENCIA\n18 DE PS OC ZR OI P / C FOIÓ RN M - AB CO IÓM NBA TIPO DE QUÍMICO C CA AN MT AID RA AD S CAP (A gC alI )DAD MATERIAL AGP (NO IT OT A TE D AN O C 1R 5IA E ) S MODELO CANTIDAD CAUDAL D (GE P I HN )YECCIÓN MODELO R (A CN pG s)O ELM E O C (hTT pRO )IR C O CANTIDAD\n19 (NOTA 15)\n20 Se requiere una unidad paquete de Preparación y Dosificación sobre patín,\n21 conformada al menos por: Un tanque horizontal de 1056 galones de acero inoxidable\n304ss con dos cámaras de preparación, y una camara para dosificación. Este paquete POLIMERO\n22 también incluye un sistema de control automático para la entrada de agua, para la ANIÓNICO\nintroducción del polímero sólido, agitacion, alarma para vaciado y llenado. para la LIQUIDO.'),
#   Document(metadata={'kv': '{"presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '42_4', 'prio': 'hoja_datos', 'type': 'text', 'page': 42}, page_content='2 2 23 4 5 (NOS ET TCA A3P 1 8) d i u s cn i ao n sy js ae atei c sf ( mi 1c c (i )a a Pó c dn odi e o ted e n re nce cd osp ie np aob ta ,l rí e l om Id n lc oe sPo r ta rn Lo uc t Cla mcí qr i do euc en nio d da tn ao id c c au ap iósn dr n ea op ,p o( a Ia1 r n r g) sma eb td ro so o ut tm o mid orb ne eea a ns1 r td H e o to l sop és dc, yi 1 af t i r C2 sc ic a o- lo a d n1 s so t8 r. r of a E ug l nlpd N p che Eia od @ Mq ni ua e A ef 1 sr t 0a e 4d0g Xecpm lo . s pa n Li, a t a p aA q sa r u P ar bea I oc t 6 el moa ,7 n bs5 u au, sn sc on Aut Po A Sn O No OL Im d ÓI Lí Mai INa Ds E Id OCRo O .Os (2) DP MT r oaR e sdpE ifua iS crr aa a ( cc c3 ii ioo) o: nn n 1056gal INO SX .S 3 .04 PR (NO O1 V T EH AEp D 1 6O )R PROVEEDOR 1 Una (( 11 )1 ) B8 B o oG mmP bbH aa d@ o ep 1 e Rr0 ea0'),
#   Document(metadata={'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 42, 'type': 'text', 'kv': '{"presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}', 'chunk_id': '42_5'}, page_content='PR (NO O1 V T EH AEp D 1 6O )R PROVEEDOR 1 Una (( 11 )1 ) B8 B o oG mmP bbH aa d@ o ep 1 e Rr0 ea0 st i pvp a as s li d + o. Una PROVEEDOR 5 P0 R (0 NO O- V 1 TE0 AE0 0 D 1C 6O )p Rs 1 Hp 1 + 1'),
#   Document(metadata={'chunk_id': '42_6', 'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'kv': '{"presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}', 'page': 42, 'type': 'text'}, page_content='dosificaran químico aniónico hacia el patín de almacenamiento Tanques de Autonomia : Tres\n26 Decantación ATR-7551 A/B/C/D/E/F Cabezal de Línea 8"-PWA-751407-AA1A33-01- (3) dias.\nAFC4 N-0.0" (NOTA 19)\n27 E Rl J P 45L C y dd ee b fe rir bá a c oo pn tit ca ar con modulos de comunicación modbus TCP/IJP con pupertos AFC4\n28\n29 MATERIALES BOMBA\n30 TIPO DE QUÍMICO\nPARTES\n31 POLIMERO ANIÓNICO PARA RETROLAVADOS\n32 LIQUID END Stainless Steel\n33 CONTOUR PLATE POR PROVEEDOR\n34 HYDRAULIC DIAPHRAGM Solid PTFE\n35 PLUNGER POR PROVEEDOR\n36 FRAME POR PROVEEDOR\n37 TUBERÍAS DE INTERCONEXIÓN Stainless Steel\n43 REQUISITOS DE LA UNIDAD DEL PAQUETE\n44 PANEL ELÉCTRICO \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06c OBSERVACIONES (NOTA 2)\n45 PANEL DE CONTROL \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06c OBSERVACIONES (NOTA 2)'),
#   Document(metadata={'type': 'text', 'prio': 'hoja_datos', 'kv': '{"presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}', 'chunk_id': '42_7', 'page': 42, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}, page_content='45 PANEL DE CONTROL \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06c OBSERVACIONES (NOTA 2)\n46 CABLEADO ELÉCTRICO \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06c OBSERVACIONES AL INTERIOR DEL PATÍN\n47 SKID \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES\n48 BORDE DE PATÍN ELÉCTRICO \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES\n49 TUBERÍA INSTRUMENTACIÓN \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06c OBSERVACIONES SS - 316\n50 PLACA DE MAMPARO DE TUBOS \uf06d POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES\n51 INSTRUMENTOS \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06c OBSERVACIONES VER P&ID: CAS-09991-PRO-PID-000012 (NOTA 2)\n52 CHECKOUT INSTRUMENTOS \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES\n53 SKID EDGE INSTRUMENT J.B. \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES\n54 FUSIBLE PLUG LOOP SYSTEM \uf06d POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES'),
#   Document(metadata={'page': 42, 'type': 'text', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'chunk_id': '42_8', 'kv': '{"presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}', 'prio': 'hoja_datos'}, page_content='54 FUSIBLE PLUG LOOP SYSTEM \uf06d POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES\n55 PINTURA \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06c OBSERVACIONES ESTÁNDARES DE FABRICANTE (NOTA 3)\n56 TUBERÍAS DE EQUIPOS \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06c OBSERVACIONES VER P&ID: CAS-09991-PRO-PID-000012 (NOTA 6)\n57 AISLAMIENTO DE EQUIPOS/TUBERÍAS \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES\n58 SOPORTE DE TUBERÍA \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06c OBSERVACIONES (NOTA 6)\n59 PRUEBA HÍDROSTATICA DE TUBERÍAS \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES\n60 INSPECCIÓN Y PRUEBA \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES\n61 OTROS: \uf06d POR PROVEEDOR \uf06d POR COMPRADOR \uf06c OBSERVACIONES QUILL DE INYECCIÓN VER SECCIÓN INYECTORES\n62\n63 MOTOR ELÉCTRICO (NOTA 14)\n64 POTENCIA 5 kW Estimada VELOCIDAD (RPM) 1800 FRAME POR PROVEEDOR'),
#   Document(metadata={'chunk_id': '42_9', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'hoja_datos', 'kv': '{"presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}', 'type': 'text', 'page': 42}, page_content='62\n63 MOTOR ELÉCTRICO (NOTA 14)\n64 POTENCIA 5 kW Estimada VELOCIDAD (RPM) 1800 FRAME POR PROVEEDOR\n65 ENCLOSURE TEFC VOLTAJE (Vac/Ph/Hz) 480Vac / 3Ph / 60Hz SERVICE FACTOR 1.0\n66 AISLAMIENTO F CLASIFICACIÓN TEMP. RISE CLASE B NORMA APLICABLE NEMA MG-1\n67\n68 INSPECCIÓN Y PRUEBAS (SEGÚN CÓDIGO DE CADA EQUIPO) (NOTA 7)\n69 PRUEBA NON-WIT. WITNESS OBSERVE CERTIFIC. EXAMEN NO DESTRUCTIVO OBSERVACIONES\n70 DESEMPEÑO \uf06c \uf06d \uf06d \uf06c \uf06c PARTÍCULAS MAGNÉTICAS TANQUE Y BOMBAS\n71 HIDROSTÁTICA \uf06c \uf06d \uf06d \uf06c \uf06d RADIOGRAFÍA APLICADO A UNIDAD PAQUETE\n72 PRUEBA DE FABRICA \uf06c \uf06d \uf06d \uf06c \uf06d TINTAS PENETRANTES TANQUE Y BOMBAS\n73 UNIDAD COMPLETA \uf06c \uf06d \uf06d \uf06d \uf06c CERTIFICADOS DE MATERIAL APLICADO A UNIDAD PAQUETE\n74 OTROS: API 675 BOMBAS DE DESPLAZAMIENTO POSITIVO - VOL. CONTROLADO \uf06d OTROS:\n75\n76 PREPARACIÓN DE ENVÍO'),
# ...
#   Document(metadata={'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 42, 'type': 'table', 'kv': '{"caudal_gph": "12-18", "presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "rango_cps_min": "500", "rango_cps_max": "1000", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}', 'prio': 'hoja_datos', 'chunk_id': '42_2'}, page_content='| CLASIFICACIÓN ELÉCTRICA CLASE GRUPO DIVISIÓN\nNO CLASIFICADA (NOTA 12) OTROS CLASE GRUPO DIVISIÓN | | | | | | | | | | | | | | | | | | | | \n | ALTITUD (ft.a.s.l) 1148 PRESIÓN ATMOSF. (psia) 14.3 TEMPERATURA AMBIEN. (ºF) 65,7 - 92,5\nHUMEDAD (%) 65 - 90 ZONA CLIMÁTICA TROPICAL / HÚMEDO ZONA SÍSMICA ALTA\nFACTOR DE IMPORTANCIA (NSR 10) 1.25 FACTOR DE ZONA (NSR 10) Aa = 0,20 Av = 0,25 VEL. MÁX. VIENTO (km/h) 120 | | | | | | | | | | | | | | | | | | | | \n | CONDICIONES DE UTILIDAD | | | | | | | | | | | | | | | | | | | | \n | VOLTAJE ELÉCTRICO (Vac/Ph/Hz) 480 VAC / 3 Ph / 60Hz VOLTAJE DE CONTROL (Vac/Ph/Hz)\nPROTOCOLO DE COMUNICACIÓN MODBUS TCP/IP PRESIÓN DE SUMINISTRO DE AIRE (psig) AIRE INSTRUMENTACIÓN 40 psig'),
#   Document(metadata={'kv': '{"caudal_gph": "12-18", "presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "rango_cps_min": "500", "rango_cps_max": "1000", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 42, 'prio': 'hoja_datos', 'chunk_id': '42_3', 'type': 'table'}, page_content='SUMINISTRO DE AGUA AFC4 100 gpm AGUA FILTRADA ( NOTA 30) | | | | | | | | | | | | | | | | | | | | \n | CÓDIGOS DE DISEÑO Y CONSTRUCCIÓN APLICABLES (NOTA 4) | | | | | | | | | | | | | | | | | | | | \n | \uf06c NEMA \uf06c NFPA \uf06c ANSI \uf06c AWS \uf06c NSR \uf06c OSHA \uf06c RETIE \uf06c API \uf06d OTROS: | | | | | | | | | | | | | | | | | | | | \n | TABLA 1. DATOS DE DISEÑO DE PROCESO Y EQUIPO DE UNIDAD DE PAQUETE (NOTA 2) | | | | | | | | | | | | | | | | | | | | \n16 | | | | | | TANQUE DE PREPARACION | | | | | | | | | | BOMBAS DE DOSIFICACION CASO MEDIO | | | | | \n17\n18\n19 | NÓICATSE | DESCRIPCIÓN - BOMBA\nPOZO / FORMACIÓN | | | | TIPO DE QUÍMICO | CANTIDAD\nCAMARAS | CAPACIDAD\n(gal) | | MATERIAL | | POTENCIA\nAGITADORES\n(NOTA 15) | | MODELO | CANTIDAD | CAUDAL DE INYECCIÓN\n(GPH) | | MODELO | RANGO\n(Cps) | POTENCIA\nMOTOR\nELECTRICO\n(hp)'),
#   Document(metadata={'prio': 'hoja_datos', 'kv': '{"caudal_gph": "12-18", "presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "rango_cps_min": "500", "rango_cps_max": "1000", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}', 'page': 42, 'chunk_id': '42_5', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'table'}, page_content='una (1) de respaldo accionadas por motores eléctricos. El paquete contara con un\nsistema de control PLC dedicado a gestionar todas las funciones del paquete, sus\ncajas (Potencia, Instrumentación, Instrumentos y Control NEMA 4X. Las bombas\ndosificaran químico aniónico hacia el patín de almacenamiento Tanques de\nDecantación ATR-7551 A/B/C/D/E/F Cabezal de Línea 8"-PWA-751407-AA1A33-01-\nN-0.0"\nEl PLC deberá contar con modulos de comunicación modbus TCP/IJP con pupertos\nRJ45 y de friba optica | | | | POLIMERO\nANIÓNICO\nLIQUIDO.\nAutonomia dos (2)\ndías\nPOLIMERO\nANIÓNICO\nSOLIDO.\nAutonomia : Tres\n(3) dias.\n(NOTA 19)\nAFC4 | TRES (3):\nPreparacion\nMaduracion\nDosificacion | 1056gal | | INOX 304\nS.S. | | 1 Hp\nPROVEEDOR\n(NOTA 16) | | PROVEEDOR | 1 | 18 GPH @ 100 psi\nUna (1) Bomba operativas + Una'),
#   Document(metadata={'chunk_id': '42_7', 'type': 'table', 'page': 42, 'kv': '{"caudal_gph": "12-18", "presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "rango_cps_min": "500", "rango_cps_max": "1000", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}', 'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}, page_content='| FRAME | | POR PROVEEDOR | | | | | | | | | | | | | | | | | | \n | TUBERÍAS DE INTERCONEXIÓN | | Stainless Steel | | | | | | | | | | | | | | | | | | \n | REQUISITOS DE LA UNIDAD DEL PAQUETE | | | | | | | | | | | | | | | | | | | | \n44\n45\n46 | PANEL ELÉCTRICO \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06c OBSERVACIONES\nPANEL DE CONTROL \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06c OBSERVACIONES\nCABLEADO ELÉCTRICO \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06c OBSERVACIONES | | | | | | | | | | | | | (NOTA 2) | | | | | | | \n | | | | | | | | | | | | | | (NOTA 2) | | | | | | | \n | | | | | | | | | | | | | | AL INTERIOR DEL PATÍN | | | | | | | \n47\n48\n49\n50 | SKID \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES\nBORDE DE PATÍN ELÉCTRICO \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES'),
#   Document(metadata={'chunk_id': '42_8', 'kv': '{"caudal_gph": "12-18", "presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "rango_cps_min": "500", "rango_cps_max": "1000", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}', 'type': 'table', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'page': 42, 'prio': 'hoja_datos'}, page_content='BORDE DE PATÍN ELÉCTRICO \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES\nTUBERÍA INSTRUMENTACIÓN \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06c OBSERVACIONES SS - 316\nPLACA DE MAMPARO DE TUBOS \uf06d POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES | | | | | | | | | | | | | | | | | | | | \n51 | INSTRUMENTOS \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06c OBSERVACIONES | | | | | | | | | | | | | VER P&ID: CAS-09991-PRO-PID-000012 (NOTA 2) | | | | | | | \n52\n53\n54\n55 | CHECKOUT INSTRUMENTOS \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES\nSKID EDGE INSTRUMENT J.B. \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES\nFUSIBLE PLUG LOOP SYSTEM \uf06d POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES\nPINTURA \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06c OBSERVACIONES ESTÁNDARES DE FABRICANTE (NOTA 3) | | | | | | | | | | | | | | | | | | | |'),
#   Document(metadata={'prio': 'hoja_datos', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'table', 'kv': '{"caudal_gph": "12-18", "presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "rango_cps_min": "500", "rango_cps_max": "1000", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}', 'page': 42, 'chunk_id': '42_9'}, page_content='56 | TUBERÍAS DE EQUIPOS \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06c OBSERVACIONES | | | | | | | | | | | | | VER P&ID: CAS-09991-PRO-PID-000012 (NOTA 6) | | | | | | | \n57 | AISLAMIENTO DE EQUIPOS/TUBERÍAS | | | \uf06c | POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES | | | | | | | | | | | | | | | | \n58\n59\n60\n61\n62\n63\n64\n65\n66\n67\n68\n69\n70\n71\n72\n73\n74\n75\n76\n77\n78\n79\n80\n81 | SOPORTE DE TUBERÍA \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06c OBSERVACIONES (NOTA 6)\nPRUEBA HÍDROSTATICA DE TUBERÍAS \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES\nINSPECCIÓN Y PRUEBA \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES\nOTROS: \uf06d POR PROVEEDOR \uf06d POR COMPRADOR \uf06c OBSERVACIONES QUILL DE INYECCIÓN VER SECCIÓN INYECTORES | | | | | | | | | | | | | | | | | | | | \n | MOTOR ELÉCTRICO (NOTA 14) | | | | | | | | | | | | | | | | | | | |'),
#   Document(metadata={'prio': 'hoja_datos', 'chunk_id': '42_10', 'type': 'table', 'page': 42, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'kv': '{"caudal_gph": "12-18", "presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "rango_cps_min": "500", "rango_cps_max": "1000", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}'}, page_content='| MOTOR ELÉCTRICO (NOTA 14) | | | | | | | | | | | | | | | | | | | | \n | POTENCIA 5 kW Estimada VELOCIDAD (RPM) 1800 FRAME POR PROVEEDOR\nENCLOSURE TEFC VOLTAJE (Vac/Ph/Hz) 480Vac / 3Ph / 60Hz SERVICE FACTOR 1.0\nAISLAMIENTO F CLASIFICACIÓN TEMP. RISE CLASE B NORMA APLICABLE NEMA MG-1 | | | | | | | | | | | | | | | | | | | | \n | INSPECCIÓN Y PRUEBAS (SEGÚN CÓDIGO DE CADA EQUIPO) (NOTA 7) | | | | | | | | | | | | | | | | | | | | \n | PRUEBA NON-WIT. WITNESS OBSERVE CERTIFIC. EXAMEN NO DESTRUCTIVO OBSERVACIONES\nDESEMPEÑO \uf06c \uf06d \uf06d \uf06c \uf06c PARTÍCULAS MAGNÉTICAS TANQUE Y BOMBAS\nHIDROSTÁTICA \uf06c \uf06d \uf06d \uf06c \uf06d RADIOGRAFÍA APLICADO A UNIDAD PAQUETE\nPRUEBA DE FABRICA \uf06c \uf06d \uf06d \uf06c \uf06d TINTAS PENETRANTES TANQUE Y BOMBAS\nUNIDAD COMPLETA \uf06c \uf06d \uf06d \uf06d \uf06c CERTIFICADOS DE MATERIAL APLICADO A UNIDAD PAQUETE'),
#   Document(metadata={'type': 'table', 'page': 42, 'prio': 'hoja_datos', 'chunk_id': '42_11', 'kv': '{"caudal_gph": "12-18", "presion_psig": "40", "hp_motor": "1", "kw_motor": "5", "rango_cps_min": "500", "rango_cps_max": "1000", "bombas_operativas": "1", "bombas_respaldo": "1", "material_tanque": "304SS", "material_mojado": "316SS", "api_675": "true"}', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}, page_content='UNIDAD COMPLETA \uf06c \uf06d \uf06d \uf06d \uf06c CERTIFICADOS DE MATERIAL APLICADO A UNIDAD PAQUETE\nOTROS: API 675 BOMBAS DE DESPLAZAMIENTO POSITIVO - VOL. CONTROLADO \uf06d OTROS: | | | | | | | | | | | | | | | | | | | | \n | PREPARACIÓN DE ENVÍO | | | | | | | | | | | | | | | | | | | | \n | PREPARACIÓN DOMÉSTICA: \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES\nCAJA DE EXPORTACIÓN: \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES\nDESCARGA DEL EQUIPO: \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES\nAMARRE DEL EQUIPO: \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES\nMATERIALES DE AMARRE: \uf06c POR PROVEEDOR \uf06d POR COMPRADOR \uf06d OBSERVACIONES | | | | | | | | | | | | | | | | | | | |'),
#   Document(metadata={'page': 43, 'chunk_id': '43_2', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'type': 'table', 'kv': '{"caudal_gph": "12-18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'prio': 'hoja_datos'}, page_content='87 | | | | | | | | | | | | | \n88\n89 | REQUERIMIENTOS DE SERVICIO | | | | | | | | | | | | \n90\n91 | EN LAS INSTALA | | CIONES DEL PROVEEDOR: \uf06c | | CHECKOUT DE CONTINUIDAD \uf06c | | | CHECKOUT DE LA FUNCIONALIDAD DEL CONTROL \uf06c | | | AJUSTE DE LA VÁLVULA DE ALIVIO (PSIG) POR PROVEEDOR \uf06c | | \n | AT PURCHASER | | SITE: \uf06c | | SERVICIO EN CAMPO/ASISTENCIA DE PUESTA EN MARCHA (DÍAS): \uf06c | | | | | | POR PROVEEDOR (NOTA 10) \uf06c | | \n92\n93\n94 | NOTAS | | | | | | | | | | | | \n | 1 El PROVEEDOR deberá confirmar y completar la información en la hoja de datos según sea necesario para la selección adecuada del patín y sus componentes. | | | | | | | | | | | | \n95\n96\n97'),
#   Document(metadata={'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'kv': '{"caudal_gph": "12-18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'prio': 'hoja_datos', 'type': 'table', 'page': 43, 'chunk_id': '43_7'}, page_content='| El PROVEEDOR deberá brindar asistencia técnica durante los trabajos de campo de montaje, inspecciones, pruebas, precomisionado, comisionado y puesta en marcha de la unidad completa. El PROVEEDOR deberá adicionalmente indicar en la oferta los días sugeridos de asistencia técnica y servicio de campo, lo\n10 que garantiza tiempo suficiente para el acompañamiento en las pruebas, pre-comisionado, comisionado y puesta en marcha de la unidad completa. | | | | | | | | | | | | \n | 11 El PROVEEDOR será el responsable de la selección de la instrumentación asociada al paquete y deberá cumplir con el documento Ecopetrol, EDP-P-013 ANEXO LISTADO MARCAS HOMOLOGADAS, en su última versión. | | | | | | | | | | | |'),
#   Document(metadata={'type': 'table', 'chunk_id': '43_8', 'kv': '{"caudal_gph": "12-18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'page': 43, 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'hoja_datos'}, page_content='| De acuerdo con revsion de la ficha de datos de seguridad para el producto MC MX 7-4240 capitulo 15 " información reglamentaria" se indica que el producto que se suministrara corresponde a grado de inflamabilidad 1 (precalentamiento mayor a 93°C) de lo cual se concluye que el polimero que se suminstrara para la\n12 inyeccion y tratamiento del agua es un compuesto muy pesado, en consecuencia, no evapora y no es inflamable a temperatura ambiente. por consiguiente, se considera que el area no es clasificada y se confirma que para el tablero del paquete de inyección de quimicos tendrá como mínimo grado de protección NEMA\n4X | | | | | | | | | | | | \n107'),
#   Document(metadata={'chunk_id': '43_9', 'type': 'table', 'prio': 'hoja_datos', 'page': 43, 'kv': '{"caudal_gph": "12-18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf'}, page_content='4X | | | | | | | | | | | | \n107\n108 | 13 | Los valores de potencia indicadas son estimados y pueden variar de acuerdo con el modelo de equipo finalmente comprado por el cliente. AFC4 | | | | | | | | | | | \n | 14 | El PROVEEDOR deberá verificar y garantizar que los equipos cumplan con las capacidades operativas especificadas. Es responsabilidad del PROVEEDOR el cálculo y suministro de los Quills de inyección. | | | | | | | | | | | \n109\n110 | Cada paquete deberá contar con instrumentación local como mínimo: para la indicación de los niveles de los tanques, indicadores de presión, reguladores y cualquier otro que indique el PROVEEDOR necesario para la correcta operación del sistema de inyección de químicos. Esta instrumentación debe ser electrónica,'),
#   Document(metadata={'chunk_id': '43_11', 'kv': '{"caudal_gph": "12-18", "presion_psig": "100", "hp_motor": "1", "material_tanque": "304SS", "api_675": "true"}', 'source': './data/CAS09991MERMR000003_InyeccionQxSTAPEC3_4_250429_200355.pdf', 'prio': 'hoja_datos', 'page': 43, 'type': 'table'}, page_content='112\n113 | 17 Eliminada AFC4 | | | | | | | | | | | | \n | 18 La ubicación del equipo es el SHELTER donde se encuentra ubicado el paquete de polímero aniónico del STAP 6. | | | | | | | | | | | | \n114 | 19 | La autonomía inicial es de dos (2) dias en fase liquida pero el paquete deberá tener una autonomia en contingencia de 3 (tres) días en fase solidad, para un total de cinco (5) dias. AFC4 | | | | | | | | | | | \n115 | 20 | En las ediciones anteriores, las notas numeradas como 8,12, 13, 18, 19, 20, 21, 22, 28, 29. Se han eliminado debido a un cambio en el propósito del proyecto. | | | | | | | | | | |')],
#  'datos': {'caudal_gph': '18',
#   'presion_psig': '100',
#   'hp_motor': '1',
#   'materiales': {'304SS', '316SS'},
#   'api_675': True,
#   'bombas_operativas': '1',
#   'bombas_respaldo': '1',
#   'paginas_fuente': {6, 9, 17, 20, 32, 37, 38, 42, 43, 61, 67, 68}}}
